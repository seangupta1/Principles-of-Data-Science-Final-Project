# %% [markdown]
# # Imports & Setup

# %% [markdown]
# ## Imports

# %%
# Imports
import numpy as np
import random
import statistics

from typing import Literal, List

import os

import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image

from torchvision.transforms import v2 as T
import torchvision.transforms.functional as F

import torch.optim as optim

import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torchvision.models as models

from tqdm.notebook import tqdm

# %% [markdown]
# ## Set Seed For Reproducibility

# %%
# Sets random seeds for reproducibility
def set_seed(seed):
    # Set seed for PyTorch
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        # Set seed for all available GPUs
        torch.cuda.manual_seed_all(seed)

    # Set seed for NumPy
    np.random.seed(seed)

    # Set seed for Python's built-in random module
    random.seed(seed)

    # Enable deterministic algorithms for reproducibility
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    # Use deterministic algorithms where available
    torch.use_deterministic_algorithms(True)

# Set random seeds
my_seed = 42
set_seed(my_seed)

# %% [markdown]
# ## Files Loading

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Config
# Path to dataset (Each group member may need to modify this)
DATASET_CLEAR_FILEPATH_IN_DRIVE = "/content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/data_clean/data_clean_v3.zip"

# %%
# Copy data clean zip from Google Drive
# !cp "{DATASET_CLEAR_FILEPATH_IN_DRIVE}" "/content/data.zip"

# %%
# Unzip data raw zip
# !unzip "/content/data.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data_clean/Train/Fake/fake_51216.jpg_0
#   inflating: data_clean/Train/Fake/fake_20451.jpg_0
#   inflating: data_clean/Train/Fake/fake_23564.jpg_0
#   inflating: data_clean/Train/Fake/fake_52180.jpg_0
#   inflating: data_clean/Train/Fake/fake_14623.jpg_1
#   inflating: data_clean/Train/Fake/fake_6036.jpg_0
#   inflating: data_clean/Train/Fake/fake_30158.jpg_0
#   inflating: data_clean/Train/Fake/fake_29598.jpg_0
#   inflating: data_clean/Train/Fake/fake_15116.jpg_0
#   inflating: data_clean/Train/Fake/fake_46947.jpg_0
#   inflating: data_clean/Train/Fake/fake_34492.jpg_0
#   inflating: data_clean/Train/Fake/fake_2002.jpg_0
#   inflating: data_clean/Train/Fake/fake_10953.jpg_0
#   inflating: data_clean/Train/Fake/fake_10916.jpg_0
#   inflating: data_clean/Train/Fake/fake_16158.jpg_1
#   inflating: data_clean/Train/Fake/fake_32262.jpg_1
#   inflating: data_clean/Train/Fake/fake_59548.jpg_0
#   inflating: data_clean/Train/Fake/fake_6142.jpg_1
#   inflating: data_clean/Train/Fake/fake_48413.jpg_0
#   inflating: data_clean/Train/Fake/fake_17590.jpg_0
#   inflating: data_clean/Train/Fake/fake_62178.jpg_0
#   inflating: data_clean/Train/Fake/fake_44364.jpg_0
#   inflating: data_clean/Train/Fake/fake_60429.jpg_0
#   inflating: data_clean/Train/Fake/fake_49392.jpg_0
#   inflating: data_clean/Train/Fake/fake_30553.jpg_1
#   inflating: data_clean/Train/Fake/fake_16376.jpg_1
#   inflating: data_clean/Train/Fake/fake_56419.jpg_0
#   inflating: data_clean/Train/Fake/fake_68128.jpg_0
#   inflating: data_clean/Train/Fake/fake_54876.jpg_0
#   inflating: data_clean/Train/Fake/fake_36051.jpg_0
#   inflating: data_clean/Train/Fake/fake_56394.jpg_0
#   inflating: data_clean/Train/Fake/fake_48982.jpg_0
#   inflating: data_clean/Train/Fake/fake_46360.jpg_0
#   inflating: data_clean/Train/Fake/fake_3679.jpg_1
#   inflating: data_clean/Train/Fake/fake_67596.jpg_0
#   inflating: data_clean/Train/Fake/fake_12845.jpg_0
#   inflating: data_clean/Train/Fake/fake_8500.jpg_0
#   inflating: data_clean/Train/Fake/fake_11659.jpg_1
#   inflating: data_clean/Train/Fake/fake_64943.jpg_0
#   inflating: data_clean/Train/Fake/fake_68138.jpg_0
#   inflating: data_clean/Train/Fake/fake_65704.jpg_0
#   inflating: data_clean/Train/Fake/fake_16901.jpg_0
#   inflating: data_clean/Train/Fake/fake_35034.jpg_0
#   inflating: data_clean/Train/Fake/fake_33809.jpg_0
#   inflating: data_clean/Train/Fake/fake_43212.jpg_0
#   inflating: data_clean/Train/Fake/fake_3616.jpg_1
#   inflating: data_clean/Train/Fake/fake_3273.jpg_0
#   inflating: data_clean/Train/Fake/fake_31038.jpg_0
#   inflating: data_clean/Train/Fake/fake_14340.jpg_0
#   inflating: data_clean/Train/Fake/fake_7363.jpg_0
#   inflating: data_clean/Train/Fake/fake_67159.jpg_1
#   inflating: data_clean/Train/Fake/fake_16956.jpg_1
#   inflating: data_clean/Train/Fake/fake_15953.jpg_0
#   inflating: data_clean/Train/Fake/fake_58944.jpg_0
#   inflating: data_clean/Train/Fake/fake_12834.jpg_1
#   inflating: data_clean/Train/Fake/fake_50583.jpg_0
#   inflating: data_clean/Train/Fake/fake_34398.jpg_0
#   inflating: data_clean/Train/Fake/fake_15503.jpg_1
#   inflating: data_clean/Train/Fake/fake_56010.jpg_0
#   inflating: data_clean/Train/Fake/fake_22148.jpg_0
#   inflating: data_clean/Train/Fake/fake_9609.jpg_0
#   inflating: data_clean/Train/Fake/fake_51341.jpg_0
#   inflating: data_clean/Train/Fake/fake_8897.jpg_0
#   inflating: data_clean/Train/Fake/fake_5689.jpg_0
#   inflating: data_clean/Train/Fake/fake_3614.jpg_0
#   inflating: data_clean/Train/Fake/fake_30791.jpg_1
#   inflating: data_clean/Train/Fake/fake_3502.jpg_1
#   inflating: data_clean/Train/Fake/fake_68316.jpg_0
#   inflating: data_clean/Train/Fake/fake_8514.jpg_0
#   inflating: data_clean/Train/Fake/fake_26879.jpg_0
#   inflating: data_clean/Train/Fake/fake_1472.jpg_0
#   inflating: data_clean/Train/Fake/fake_7557.jpg_0
#   inflating: data_clean/Train/Fake/fake_12086.jpg_0
#   inflating: data_clean/Train/Fake/fake_63437.jpg_0
#   inflating: data_clean/Train/Fake/fake_18246.jpg_0
#   inflating: data_clean/Train/Fake/fake_13337.jpg_0
#   inflating: data_clean/Train/Fake/fake_16689.jpg_0
#   inflating: data_clean/Train/Fake/fake_58375.jpg_2
#   inflating: data_clean/Train/Fake/fake_51918.jpg_0
#   inflating: data_clean/Train/Fake/fake_50227.jpg_0
#   inflating: data_clean/Train/Fake/fake_16391.jpg_0
#   inflating: data_clean/Train/Fake/fake_33574.jpg_0
#   inflating: data_clean/Train/Fake/fake_54557.jpg_1
#   inflating: data_clean/Train/Fake/fake_60238.jpg_0
#   inflating: data_clean/Train/Fake/fake_35220.jpg_0
#   inflating: data_clean/Train/Fake/fake_69014.jpg_1
#   inflating: data_clean/Train/Fake/fake_47928.jpg_0
#   inflating: data_clean/Train/Fake/fake_4486.jpg_2
#   inflating: data_clean/Train/Fake/fake_36459.jpg_0
#   inflating: data_clean/Train/Fake/fake_15572.jpg_0
#   inflating: data_clean/Train/Fake/fake_60828.jpg_1
#   inflating: data_clean/Train/Fake/fake_16480.jpg_0
#   inflating: data_clean/Train/Fake/fake_44381.jpg_0
#   inflating: data_clean/Train/Fake/fake_54380.jpg_0
#   inflating: data_clean/Train/Fake/fake_317.jpg_0
#   inflating: data_clean/Train/Fake/fake_48114.jpg_0
#   inflating: data_clean/Train/Fake/fake_48269.jpg_0
#   inflating: data_clean/Train/Fake/fake_24157.jpg_0
#   inflating: data_clean/Train/Fake/fake_40508.jpg_0
#   inflating: data_clean/Train/Fake/fake_19578.jpg_0
#   inflating: data_clean/Train/Fake/fake_33027.jpg_1
#   inflating: data_clean/Train/Fake/fake_64755.jpg_1
#   inflating: data_clean/Train/Fake/fake_2844.jpg_0
#   inflating: data_clean/Train/Fake/fake_30628.jpg_0
#   inflating: data_clean/Train/Fake/fake_35203.jpg_3
#   inflating: data_clean/Train/Fake/fake_17193.jpg_0
#   inflating: data_clean/Train/Fake/fake_20001.jpg_2
#   inflating: data_clean/Train/Fake/fake_14363.jpg_0
#   inflating: data_clean/Train/Fake/fake_18578.jpg_1
#   inflating: data_clean/Train/Fake/fake_39419.jpg_0
#   inflating: data_clean/Train/Fake/fake_12830.jpg_0
#   inflating: data_clean/Train/Fake/fake_11245.jpg_0
#   inflating: data_clean/Train/Fake/fake_66029.jpg_0
#   inflating: data_clean/Train/Fake/fake_68942.jpg_0
#   inflating: data_clean/Train/Fake/fake_29087.jpg_0
#   inflating: data_clean/Train/Fake/fake_19673.jpg_0
#   inflating: data_clean/Train/Fake/fake_51908.jpg_0
#   inflating: data_clean/Train/Fake/fake_22577.jpg_1
#   inflating: data_clean/Train/Fake/fake_11883.jpg_0
#   inflating: data_clean/Train/Fake/fake_15992.jpg_0
#   inflating: data_clean/Train/Fake/fake_40127.jpg_1
#   inflating: data_clean/Train/Fake/fake_40747.jpg_0
#   inflating: data_clean/Train/Fake/fake_24142.jpg_0
#   inflating: data_clean/Train/Fake/fake_63338.jpg_0
#   inflating: data_clean/Train/Fake/fake_16653.jpg_1
#   inflating: data_clean/Train/Fake/fake_59937.jpg_0
#   inflating: data_clean/Train/Fake/fake_694.jpg_0
#   inflating: data_clean/Train/Fake/fake_8692.jpg_0
#   inflating: data_clean/Train/Fake/fake_30957.jpg_1
#   inflating: data_clean/Train/Fake/fake_39854.jpg_0
#   inflating: data_clean/Train/Fake/fake_57406.jpg_0
#   inflating: data_clean/Train/Fake/fake_30845.jpg_1
#   inflating: data_clean/Train/Fake/fake_23602.jpg_0
#   inflating: data_clean/Train/Fake/fake_47050.jpg_0
#   inflating: data_clean/Train/Fake/fake_55978.jpg_0
#   inflating: data_clean/Train/Fake/fake_4239.jpg_0
#   inflating: data_clean/Train/Fake/fake_57168.jpg_1
#   inflating: data_clean/Train/Fake/fake_14460.jpg_2
#   inflating: data_clean/Train/Fake/fake_25081.jpg_0
#   inflating: data_clean/Train/Fake/fake_56708.jpg_1
#   inflating: data_clean/Train/Fake/fake_19098.jpg_0
#   inflating: data_clean/Train/Fake/fake_24465.jpg_0
#   inflating: data_clean/Train/Fake/fake_68560.jpg_1
#   inflating: data_clean/Train/Fake/fake_36747.jpg_0
#   inflating: data_clean/Train/Fake/fake_20816.jpg_1
#   inflating: data_clean/Train/Fake/fake_67996.jpg_0
#   inflating: data_clean/Train/Fake/fake_30269.jpg_0
#   inflating: data_clean/Train/Fake/fake_36973.jpg_0
#   inflating: data_clean/Train/Fake/fake_23149.jpg_0
#   inflating: data_clean/Train/Fake/fake_23380.jpg_1
#   inflating: data_clean/Train/Fake/fake_11831.jpg_0
#   inflating: data_clean/Train/Fake/fake_62866.jpg_0
#   inflating: data_clean/Train/Fake/fake_12138.jpg_0
#   inflating: data_clean/Train/Fake/fake_2812.jpg_0
#   inflating: data_clean/Train/Fake/fake_53752.jpg_1
#   inflating: data_clean/Train/Fake/fake_28553.jpg_0
#   inflating: data_clean/Train/Fake/fake_69759.jpg_0
#   inflating: data_clean/Train/Fake/fake_68309.jpg_0
#   inflating: data_clean/Train/Fake/fake_55855.jpg_0
#   inflating: data_clean/Train/Fake/fake_51548.jpg_1
#   inflating: data_clean/Train/Fake/fake_6745.jpg_0
#   inflating: data_clean/Train/Fake/fake_49967.jpg_0
#   inflating: data_clean/Train/Fake/fake_35074.jpg_0
#   inflating: data_clean/Train/Fake/fake_44015.jpg_0
#   inflating: data_clean/Train/Fake/fake_38757.jpg_0
#   inflating: data_clean/Train/Fake/fake_37443.jpg_0
#   inflating: data_clean/Train/Fake/fake_56261.jpg_1
#   inflating: data_clean/Train/Fake/fake_30631.jpg_0
#   inflating: data_clean/Train/Fake/fake_5687.jpg_0
#   inflating: data_clean/Train/Fake/fake_2239.jpg_0
#   inflating: data_clean/Train/Fake/fake_62175.jpg_0
#   inflating: data_clean/Train/Fake/fake_36500.jpg_0
#   inflating: data_clean/Train/Fake/fake_46419.jpg_0
#   inflating: data_clean/Train/Fake/fake_50655.jpg_0
#   inflating: data_clean/Train/Fake/fake_34321.jpg_0
#   inflating: data_clean/Train/Fake/fake_35865.jpg_0
#   inflating: data_clean/Train/Fake/fake_25605.jpg_0
#   inflating: data_clean/Train/Fake/fake_7080.jpg_0
#   inflating: data_clean/Train/Fake/fake_16455.jpg_0
#   inflating: data_clean/Train/Fake/fake_52531.jpg_0
#   inflating: data_clean/Train/Fake/fake_41772.jpg_0
#   inflating: data_clean/Train/Fake/fake_20506.jpg_1
#   inflating: data_clean/Train/Fake/fake_55105.jpg_0
#   inflating: data_clean/Train/Fake/fake_3036.jpg_0
#   inflating: data_clean/Train/Fake/fake_51661.jpg_0
#   inflating: data_clean/Train/Fake/fake_54805.jpg_0
#   inflating: data_clean/Train/Fake/fake_7698.jpg_0
#   inflating: data_clean/Train/Fake/fake_14975.jpg_0
#   inflating: data_clean/Train/Fake/fake_57965.jpg_0
#   inflating: data_clean/Train/Fake/fake_36387.jpg_0
#   inflating: data_clean/Train/Fake/fake_30934.jpg_0
#   inflating: data_clean/Train/Fake/fake_5990.jpg_0
#   inflating: data_clean/Train/Fake/fake_64046.jpg_0
#   inflating: data_clean/Train/Fake/fake_34910.jpg_0
#   inflating: data_clean/Train/Fake/fake_16878.jpg_2
#   inflating: data_clean/Train/Fake/fake_61633.jpg_0
#   inflating: data_clean/Train/Fake/fake_44334.jpg_0
#   inflating: data_clean/Train/Fake/fake_24200.jpg_0
#   inflating: data_clean/Train/Fake/fake_68619.jpg_0
#   inflating: data_clean/Train/Fake/fake_28942.jpg_0
#   inflating: data_clean/Train/Fake/fake_68782.jpg_0
#   inflating: data_clean/Train/Fake/fake_62758.jpg_0
#   inflating: data_clean/Train/Fake/fake_4511.jpg_0
#   inflating: data_clean/Train/Fake/fake_4861.jpg_0
#   inflating: data_clean/Train/Fake/fake_391.jpg_0
#   inflating: data_clean/Train/Fake/fake_51069.jpg_0
#   inflating: data_clean/Train/Fake/fake_66305.jpg_1
#   inflating: data_clean/Train/Fake/fake_38088.jpg_0
#   inflating: data_clean/Train/Fake/fake_53565.jpg_0
#   inflating: data_clean/Train/Fake/fake_69110.jpg_0
#   inflating: data_clean/Train/Fake/fake_12637.jpg_0
#   inflating: data_clean/Train/Fake/fake_24064.jpg_0
#   inflating: data_clean/Train/Fake/fake_1294.jpg_0
#   inflating: data_clean/Train/Fake/fake_38310.jpg_0
#   inflating: data_clean/Train/Fake/fake_42860.jpg_0
#   inflating: data_clean/Train/Fake/fake_7326.jpg_0
#   inflating: data_clean/Train/Fake/fake_58485.jpg_1
#   inflating: data_clean/Train/Fake/fake_66474.jpg_0
#   inflating: data_clean/Train/Fake/fake_68460.jpg_0
#   inflating: data_clean/Train/Fake/fake_13397.jpg_1
#   inflating: data_clean/Train/Fake/fake_10623.jpg_0
#   inflating: data_clean/Train/Fake/fake_37956.jpg_0
#   inflating: data_clean/Train/Fake/fake_65745.jpg_0
#   inflating: data_clean/Train/Fake/fake_69885.jpg_1
#   inflating: data_clean/Train/Fake/fake_65905.jpg_0
#   inflating: data_clean/Train/Fake/fake_36688.jpg_0
#   inflating: data_clean/Train/Fake/fake_53722.jpg_0
#   inflating: data_clean/Train/Fake/fake_22133.jpg_0
#   inflating: data_clean/Train/Fake/fake_47755.jpg_0
#   inflating: data_clean/Train/Fake/fake_57986.jpg_0
#   inflating: data_clean/Train/Fake/fake_10551.jpg_0
#   inflating: data_clean/Train/Fake/fake_32746.jpg_1
#   inflating: data_clean/Train/Fake/fake_55516.jpg_0
#   inflating: data_clean/Train/Fake/fake_42721.jpg_0
#   inflating: data_clean/Train/Fake/fake_9404.jpg_0
#   inflating: data_clean/Train/Fake/fake_20408.jpg_0
#   inflating: data_clean/Train/Fake/fake_29103.jpg_0
#   inflating: data_clean/Train/Fake/fake_52391.jpg_0
#   inflating: data_clean/Train/Fake/fake_9484.jpg_0
#   inflating: data_clean/Train/Fake/fake_3081.jpg_0
#   inflating: data_clean/Train/Fake/fake_9754.jpg_0
#   inflating: data_clean/Train/Fake/fake_48279.jpg_0
#   inflating: data_clean/Train/Fake/fake_53174.jpg_0
#   inflating: data_clean/Train/Fake/fake_6409.jpg_2
#   inflating: data_clean/Train/Fake/fake_61854.jpg_0
#   inflating: data_clean/Train/Fake/fake_10806.jpg_1
#   inflating: data_clean/Train/Fake/fake_3853.jpg_0
#   inflating: data_clean/Train/Fake/fake_5704.jpg_0
#   inflating: data_clean/Train/Fake/fake_58154.jpg_0
#   inflating: data_clean/Train/Fake/fake_35752.jpg_0
#   inflating: data_clean/Train/Fake/fake_24664.jpg_0
#   inflating: data_clean/Train/Fake/fake_37785.jpg_0
#   inflating: data_clean/Train/Fake/fake_33970.jpg_1
#   inflating: data_clean/Train/Fake/fake_32638.jpg_0
#   inflating: data_clean/Train/Fake/fake_17088.jpg_0
#   inflating: data_clean/Train/Fake/fake_30114.jpg_0
#   inflating: data_clean/Train/Fake/fake_32017.jpg_1
#   inflating: data_clean/Train/Fake/fake_33165.jpg_0
#   inflating: data_clean/Train/Fake/fake_61051.jpg_0
#   inflating: data_clean/Train/Fake/fake_62441.jpg_0
#   inflating: data_clean/Train/Fake/fake_29321.jpg_0
#   inflating: data_clean/Train/Fake/fake_43069.jpg_1
#   inflating: data_clean/Train/Fake/fake_60160.jpg_0
#   inflating: data_clean/Train/Fake/fake_40437.jpg_0
#   inflating: data_clean/Train/Fake/fake_33772.jpg_0
#   inflating: data_clean/Train/Fake/fake_60370.jpg_0
#   inflating: data_clean/Train/Fake/fake_35086.jpg_0
#   inflating: data_clean/Train/Fake/fake_60750.jpg_0
#   inflating: data_clean/Train/Fake/fake_28249.jpg_0
#   inflating: data_clean/Train/Fake/fake_62350.jpg_0
#   inflating: data_clean/Train/Fake/fake_29430.jpg_0
#   inflating: data_clean/Train/Fake/fake_66288.jpg_0
#   inflating: data_clean/Train/Fake/fake_67129.jpg_0
#   inflating: data_clean/Train/Fake/fake_17001.jpg_0
#   inflating: data_clean/Train/Fake/fake_1863.jpg_0
#   inflating: data_clean/Train/Fake/fake_55791.jpg_0
#   inflating: data_clean/Train/Fake/fake_51093.jpg_1
#   inflating: data_clean/Train/Fake/fake_65363.jpg_0
#   inflating: data_clean/Train/Fake/fake_56019.jpg_0
#   inflating: data_clean/Train/Fake/fake_54594.jpg_0
#   inflating: data_clean/Train/Fake/fake_39227.jpg_0
#   inflating: data_clean/Train/Fake/fake_49496.jpg_1
#   inflating: data_clean/Train/Fake/fake_10330.jpg_0
#   inflating: data_clean/Train/Fake/fake_12893.jpg_0
#   inflating: data_clean/Train/Fake/fake_61139.jpg_1
#   inflating: data_clean/Train/Fake/fake_21444.jpg_0
#   inflating: data_clean/Train/Fake/fake_65183.jpg_0
#   inflating: data_clean/Train/Fake/fake_14776.jpg_0
#   inflating: data_clean/Train/Fake/fake_29893.jpg_0
#   inflating: data_clean/Train/Fake/fake_14261.jpg_0
#   inflating: data_clean/Train/Fake/fake_5168.jpg_2
#   inflating: data_clean/Train/Fake/fake_5179.jpg_0
#   inflating: data_clean/Train/Fake/fake_33655.jpg_0
#   inflating: data_clean/Train/Fake/fake_1423.jpg_0
#   inflating: data_clean/Train/Fake/fake_65272.jpg_2
#   inflating: data_clean/Train/Fake/fake_44306.jpg_0
#   inflating: data_clean/Train/Fake/fake_6978.jpg_0
#   inflating: data_clean/Train/Fake/fake_6961.jpg_0
#   inflating: data_clean/Train/Fake/fake_47831.jpg_0
#   inflating: data_clean/Train/Fake/fake_14616.jpg_3
#   inflating: data_clean/Train/Fake/fake_47859.jpg_0
#   inflating: data_clean/Train/Fake/fake_58829.jpg_0
#   inflating: data_clean/Train/Fake/fake_3921.jpg_1
#   inflating: data_clean/Train/Fake/fake_69287.jpg_1
#   inflating: data_clean/Train/Fake/fake_30264.jpg_1
#   inflating: data_clean/Train/Fake/fake_69916.jpg_1
#   inflating: data_clean/Train/Fake/fake_4341.jpg_2
#   inflating: data_clean/Train/Fake/fake_57693.jpg_0
#   inflating: data_clean/Train/Fake/fake_49793.jpg_0
#   inflating: data_clean/Train/Fake/fake_43437.jpg_0
#   inflating: data_clean/Train/Fake/fake_6225.jpg_0
#   inflating: data_clean/Train/Fake/fake_14961.jpg_0
#   inflating: data_clean/Train/Fake/fake_19653.jpg_2
#   inflating: data_clean/Train/Fake/fake_60139.jpg_0
#   inflating: data_clean/Train/Fake/fake_64522.jpg_0
#   inflating: data_clean/Train/Fake/fake_9459.jpg_0
#   inflating: data_clean/Train/Fake/fake_53038.jpg_0
#   inflating: data_clean/Train/Fake/fake_26163.jpg_0
#   inflating: data_clean/Train/Fake/fake_3908.jpg_2
#   inflating: data_clean/Train/Fake/fake_66114.jpg_0
#   inflating: data_clean/Train/Fake/fake_67211.jpg_0
#   inflating: data_clean/Train/Fake/fake_38592.jpg_0
#   inflating: data_clean/Train/Fake/fake_44647.jpg_0
#   inflating: data_clean/Train/Fake/fake_22334.jpg_0
#   inflating: data_clean/Train/Fake/fake_49921.jpg_0
#   inflating: data_clean/Train/Fake/fake_20753.jpg_0
#   inflating: data_clean/Train/Fake/fake_56396.jpg_0
#   inflating: data_clean/Train/Fake/fake_14434.jpg_0
#   inflating: data_clean/Train/Fake/fake_67280.jpg_0
#   inflating: data_clean/Train/Fake/fake_68661.jpg_2
#   inflating: data_clean/Train/Fake/fake_54391.jpg_0
#   inflating: data_clean/Train/Fake/fake_44167.jpg_0
#   inflating: data_clean/Train/Fake/fake_20848.jpg_2
#   inflating: data_clean/Train/Fake/fake_33740.jpg_0
#   inflating: data_clean/Train/Fake/fake_25615.jpg_0
#   inflating: data_clean/Train/Fake/fake_16950.jpg_1
#   inflating: data_clean/Train/Fake/fake_4340.jpg_1
#   inflating: data_clean/Train/Fake/fake_54921.jpg_0
#   inflating: data_clean/Train/Fake/fake_3426.jpg_1
#   inflating: data_clean/Train/Fake/fake_22216.jpg_0
#   inflating: data_clean/Train/Fake/fake_34712.jpg_0
#   inflating: data_clean/Train/Fake/fake_11054.jpg_0
#   inflating: data_clean/Train/Fake/fake_51704.jpg_0
#   inflating: data_clean/Train/Fake/fake_37547.jpg_0
#   inflating: data_clean/Train/Fake/fake_10337.jpg_0
#   inflating: data_clean/Train/Fake/fake_5812.jpg_1
#   inflating: data_clean/Train/Fake/fake_63660.jpg_0
#   inflating: data_clean/Train/Fake/fake_20680.jpg_0
#   inflating: data_clean/Train/Fake/fake_68442.jpg_0
#   inflating: data_clean/Train/Fake/fake_62766.jpg_0
#   inflating: data_clean/Train/Fake/fake_4605.jpg_0
#   inflating: data_clean/Train/Fake/fake_52303.jpg_0
#   inflating: data_clean/Train/Fake/fake_62320.jpg_0
#   inflating: data_clean/Train/Fake/fake_37910.jpg_0
#   inflating: data_clean/Train/Fake/fake_299.jpg_0
#   inflating: data_clean/Train/Fake/fake_34466.jpg_0
#   inflating: data_clean/Train/Fake/fake_20575.jpg_1
#   inflating: data_clean/Train/Fake/fake_66133.jpg_0
#   inflating: data_clean/Train/Fake/fake_54643.jpg_0
#   inflating: data_clean/Train/Fake/fake_53976.jpg_0
#   inflating: data_clean/Train/Fake/fake_9473.jpg_0
#   inflating: data_clean/Train/Fake/fake_5957.jpg_0
#   inflating: data_clean/Train/Fake/fake_31370.jpg_0
#   inflating: data_clean/Train/Fake/fake_53139.jpg_0
#   inflating: data_clean/Train/Fake/fake_28516.jpg_0
#   inflating: data_clean/Train/Fake/fake_8031.jpg_0
#   inflating: data_clean/Train/Fake/fake_43654.jpg_0
#   inflating: data_clean/Train/Fake/fake_11618.jpg_0
#   inflating: data_clean/Train/Fake/fake_69261.jpg_0
#   inflating: data_clean/Train/Fake/fake_40652.jpg_0
#   inflating: data_clean/Train/Fake/fake_7842.jpg_0
#   inflating: data_clean/Train/Fake/fake_12728.jpg_0
#   inflating: data_clean/Train/Fake/fake_32060.jpg_2
#   inflating: data_clean/Train/Fake/fake_40802.jpg_0
#   inflating: data_clean/Train/Fake/fake_56995.jpg_0
#   inflating: data_clean/Train/Fake/fake_37341.jpg_0
#   inflating: data_clean/Train/Fake/fake_10881.jpg_1
#   inflating: data_clean/Train/Fake/fake_1922.jpg_0
#   inflating: data_clean/Train/Fake/fake_20017.jpg_1
#   inflating: data_clean/Train/Fake/fake_68337.jpg_0
#   inflating: data_clean/Train/Fake/fake_20129.jpg_2
#   inflating: data_clean/Train/Fake/fake_12741.jpg_1
#   inflating: data_clean/Train/Fake/fake_33096.jpg_0
#   inflating: data_clean/Train/Fake/fake_5695.jpg_0
#   inflating: data_clean/Train/Fake/fake_21549.jpg_1
#   inflating: data_clean/Train/Fake/fake_15603.jpg_0
#   inflating: data_clean/Train/Fake/fake_63066.jpg_0
#   inflating: data_clean/Train/Fake/fake_4535.jpg_0
#   inflating: data_clean/Train/Fake/fake_29942.jpg_0
#   inflating: data_clean/Train/Fake/fake_61831.jpg_0
#   inflating: data_clean/Train/Fake/fake_51989.jpg_0
#   inflating: data_clean/Train/Fake/fake_40499.jpg_0
#   inflating: data_clean/Train/Fake/fake_54471.jpg_1
#   inflating: data_clean/Train/Fake/fake_30690.jpg_0
#   inflating: data_clean/Train/Fake/fake_17031.jpg_1
#   inflating: data_clean/Train/Fake/fake_66318.jpg_0
#   inflating: data_clean/Train/Fake/fake_13576.jpg_0
#   inflating: data_clean/Train/Fake/fake_34576.jpg_0
#   inflating: data_clean/Train/Fake/fake_18960.jpg_0
#   inflating: data_clean/Train/Fake/fake_12759.jpg_0
#   inflating: data_clean/Train/Fake/fake_65075.jpg_0
#   inflating: data_clean/Train/Fake/fake_29300.jpg_0
#   inflating: data_clean/Train/Fake/fake_43213.jpg_0
#   inflating: data_clean/Train/Fake/fake_18458.jpg_0
#   inflating: data_clean/Train/Fake/fake_24654.jpg_0
#   inflating: data_clean/Train/Fake/fake_48569.jpg_2
#   inflating: data_clean/Train/Fake/fake_36570.jpg_0
#   inflating: data_clean/Train/Fake/fake_11214.jpg_0
#   inflating: data_clean/Train/Fake/fake_27349.jpg_1
#   inflating: data_clean/Train/Fake/fake_42048.jpg_0
#   inflating: data_clean/Train/Fake/fake_54786.jpg_0
#   inflating: data_clean/Train/Fake/fake_45120.jpg_0
#   inflating: data_clean/Train/Fake/fake_68272.jpg_0
#   inflating: data_clean/Train/Fake/fake_4482.jpg_1
#   inflating: data_clean/Train/Fake/fake_31075.jpg_0
#   inflating: data_clean/Train/Fake/fake_10836.jpg_0
#   inflating: data_clean/Train/Fake/fake_24593.jpg_0
#   inflating: data_clean/Train/Fake/fake_65647.jpg_0
#   inflating: data_clean/Train/Fake/fake_66255.jpg_0
#   inflating: data_clean/Train/Fake/fake_33634.jpg_1
#   inflating: data_clean/Train/Fake/fake_67009.jpg_0
#   inflating: data_clean/Train/Fake/fake_35615.jpg_0
#   inflating: data_clean/Train/Fake/fake_56050.jpg_0
#   inflating: data_clean/Train/Fake/fake_55289.jpg_0
#   inflating: data_clean/Train/Fake/fake_69234.jpg_0
#   inflating: data_clean/Train/Fake/fake_34307.jpg_0
#   inflating: data_clean/Train/Fake/fake_62747.jpg_0
#   inflating: data_clean/Train/Fake/fake_23095.jpg_1
#   inflating: data_clean/Train/Fake/fake_12846.jpg_0
#   inflating: data_clean/Train/Fake/fake_4587.jpg_0
#   inflating: data_clean/Train/Fake/fake_56514.jpg_0
#   inflating: data_clean/Train/Fake/fake_31807.jpg_0
#   inflating: data_clean/Train/Fake/fake_28911.jpg_0
#   inflating: data_clean/Train/Fake/fake_29444.jpg_1
#   inflating: data_clean/Train/Fake/fake_26151.jpg_0
#   inflating: data_clean/Train/Fake/fake_67239.jpg_0
#   inflating: data_clean/Train/Fake/fake_30445.jpg_0
#   inflating: data_clean/Train/Fake/fake_50670.jpg_0
#   inflating: data_clean/Train/Fake/fake_34732.jpg_0
#   inflating: data_clean/Train/Fake/fake_20375.jpg_0
#   inflating: data_clean/Train/Fake/fake_12785.jpg_0
#   inflating: data_clean/Train/Fake/fake_22739.jpg_1
#   inflating: data_clean/Train/Fake/fake_68824.jpg_0
#   inflating: data_clean/Train/Fake/fake_63218.jpg_0
#   inflating: data_clean/Train/Fake/fake_15636.jpg_0
#   inflating: data_clean/Train/Fake/fake_33197.jpg_0
#   inflating: data_clean/Train/Fake/fake_57650.jpg_0
#   inflating: data_clean/Train/Fake/fake_22639.jpg_0
#   inflating: data_clean/Train/Fake/fake_69449.jpg_0
#   inflating: data_clean/Train/Fake/fake_37550.jpg_0
#   inflating: data_clean/Train/Fake/fake_51507.jpg_0
#   inflating: data_clean/Train/Fake/fake_50151.jpg_0
#   inflating: data_clean/Train/Fake/fake_55608.jpg_1
#   inflating: data_clean/Train/Fake/fake_60288.jpg_0
#   inflating: data_clean/Train/Fake/fake_64745.jpg_0
#   inflating: data_clean/Train/Fake/fake_20774.jpg_0
#   inflating: data_clean/Train/Fake/fake_29712.jpg_0
#   inflating: data_clean/Train/Fake/fake_34950.jpg_0
#   inflating: data_clean/Train/Fake/fake_61566.jpg_0
#   inflating: data_clean/Train/Fake/fake_50265.jpg_0
#   inflating: data_clean/Train/Fake/fake_17817.jpg_1
#   inflating: data_clean/Train/Fake/fake_29892.jpg_0
#   inflating: data_clean/Train/Fake/fake_68948.jpg_0
#   inflating: data_clean/Train/Fake/fake_31609.jpg_0
#   inflating: data_clean/Train/Fake/fake_66252.jpg_0
#   inflating: data_clean/Train/Fake/fake_38563.jpg_0
#   inflating: data_clean/Train/Fake/fake_12047.jpg_1
#   inflating: data_clean/Train/Fake/fake_27863.jpg_1
#   inflating: data_clean/Train/Fake/fake_36851.jpg_0
#   inflating: data_clean/Train/Fake/fake_20791.jpg_0
#   inflating: data_clean/Train/Fake/fake_40656.jpg_0
#   inflating: data_clean/Train/Fake/fake_6071.jpg_0
#   inflating: data_clean/Train/Fake/fake_27956.jpg_0
#   inflating: data_clean/Train/Fake/fake_5426.jpg_0
#   inflating: data_clean/Train/Fake/fake_26956.jpg_0
#   inflating: data_clean/Train/Fake/fake_33776.jpg_0
#   inflating: data_clean/Train/Fake/fake_27106.jpg_0
#   inflating: data_clean/Train/Fake/fake_10085.jpg_0
#   inflating: data_clean/Train/Fake/fake_24488.jpg_0
#   inflating: data_clean/Train/Fake/fake_27255.jpg_0
#   inflating: data_clean/Train/Fake/fake_4572.jpg_0
#   inflating: data_clean/Train/Fake/fake_62609.jpg_0
#   inflating: data_clean/Train/Fake/fake_32950.jpg_0
#   inflating: data_clean/Train/Fake/fake_22179.jpg_0
#   inflating: data_clean/Train/Fake/fake_56972.jpg_0
#   inflating: data_clean/Train/Fake/fake_53664.jpg_0
#   inflating: data_clean/Train/Fake/fake_43092.jpg_0
#   inflating: data_clean/Train/Fake/fake_13580.jpg_0
#   inflating: data_clean/Train/Fake/fake_14394.jpg_0
#   inflating: data_clean/Train/Fake/fake_5189.jpg_1
#   inflating: data_clean/Train/Fake/fake_58941.jpg_1
#   inflating: data_clean/Train/Fake/fake_61987.jpg_0
#   inflating: data_clean/Train/Fake/fake_62048.jpg_0
#   inflating: data_clean/Train/Fake/fake_526.jpg_0
#   inflating: data_clean/Train/Fake/fake_31304.jpg_0
#   inflating: data_clean/Train/Fake/fake_57157.jpg_2
#   inflating: data_clean/Train/Fake/fake_57808.jpg_0
#   inflating: data_clean/Train/Fake/fake_46444.jpg_1
#   inflating: data_clean/Train/Fake/fake_47536.jpg_0
#   inflating: data_clean/Train/Fake/fake_4020.jpg_0
#   inflating: data_clean/Train/Fake/fake_6819.jpg_0
#   inflating: data_clean/Train/Fake/fake_41566.jpg_0
#   inflating: data_clean/Train/Fake/fake_69036.jpg_1
#   inflating: data_clean/Train/Fake/fake_36393.jpg_0
#   inflating: data_clean/Train/Fake/fake_32422.jpg_0
#   inflating: data_clean/Train/Fake/fake_24021.jpg_0
#   inflating: data_clean/Train/Fake/fake_21510.jpg_0
#   inflating: data_clean/Train/Fake/fake_10790.jpg_0
#   inflating: data_clean/Train/Fake/fake_65760.jpg_1
#   inflating: data_clean/Train/Fake/fake_59345.jpg_0
#   inflating: data_clean/Train/Fake/fake_28325.jpg_0
#   inflating: data_clean/Train/Fake/fake_36828.jpg_0
#   inflating: data_clean/Train/Fake/fake_48529.jpg_0
#   inflating: data_clean/Train/Fake/fake_25641.jpg_0
#   inflating: data_clean/Train/Fake/fake_33724.jpg_0
#   inflating: data_clean/Train/Fake/fake_43123.jpg_0
#   inflating: data_clean/Train/Fake/fake_28688.jpg_0
#   inflating: data_clean/Train/Fake/fake_10789.jpg_0
#   inflating: data_clean/Train/Fake/fake_43663.jpg_0
#   inflating: data_clean/Train/Fake/fake_26982.jpg_0
#   inflating: data_clean/Train/Fake/fake_6035.jpg_0
#   inflating: data_clean/Train/Fake/fake_27480.jpg_0
#   inflating: data_clean/Train/Fake/fake_69251.jpg_0
#   inflating: data_clean/Train/Fake/fake_60615.jpg_0
#   inflating: data_clean/Train/Fake/fake_66443.jpg_0
#   inflating: data_clean/Train/Fake/fake_42129.jpg_0
#   inflating: data_clean/Train/Fake/fake_3882.jpg_1
#   inflating: data_clean/Train/Fake/fake_5616.jpg_0
#   inflating: data_clean/Train/Fake/fake_29944.jpg_0
#   inflating: data_clean/Train/Fake/fake_59527.jpg_2
#   inflating: data_clean/Train/Fake/fake_18146.jpg_2
#   inflating: data_clean/Train/Fake/fake_63314.jpg_1
#   inflating: data_clean/Train/Fake/fake_28773.jpg_1
#   inflating: data_clean/Train/Fake/fake_12284.jpg_0
#   inflating: data_clean/Train/Fake/fake_40786.jpg_0
#   inflating: data_clean/Train/Fake/fake_68420.jpg_0
#   inflating: data_clean/Train/Fake/fake_32432.jpg_0
#   inflating: data_clean/Train/Fake/fake_54117.jpg_0
#   inflating: data_clean/Train/Fake/fake_5950.jpg_0
#   inflating: data_clean/Train/Fake/fake_67484.jpg_0
#   inflating: data_clean/Train/Fake/fake_59293.jpg_0
#   inflating: data_clean/Train/Fake/fake_63798.jpg_1
#   inflating: data_clean/Train/Fake/fake_61000.jpg_0
#   inflating: data_clean/Train/Fake/fake_49216.jpg_0
#   inflating: data_clean/Train/Fake/fake_17780.jpg_0
#   inflating: data_clean/Train/Fake/fake_13913.jpg_2
#   inflating: data_clean/Train/Fake/fake_16814.jpg_0
#   inflating: data_clean/Train/Fake/fake_6609.jpg_0
#   inflating: data_clean/Train/Fake/fake_23439.jpg_1
#   inflating: data_clean/Train/Fake/fake_39011.jpg_0
#   inflating: data_clean/Train/Fake/fake_53809.jpg_1
#   inflating: data_clean/Train/Fake/fake_9568.jpg_0
#   inflating: data_clean/Train/Fake/fake_47844.jpg_0
#   inflating: data_clean/Train/Fake/fake_11409.jpg_0
#   inflating: data_clean/Train/Fake/fake_23464.jpg_1
#   inflating: data_clean/Train/Fake/fake_17199.jpg_1
#   inflating: data_clean/Train/Fake/fake_55546.jpg_3
#   inflating: data_clean/Train/Fake/fake_69208.jpg_0
#   inflating: data_clean/Train/Fake/fake_29135.jpg_1
#   inflating: data_clean/Train/Fake/fake_37013.jpg_0
#   inflating: data_clean/Train/Fake/fake_45778.jpg_0
#   inflating: data_clean/Train/Fake/fake_22885.jpg_0
#   inflating: data_clean/Train/Fake/fake_503.jpg_0
#   inflating: data_clean/Train/Fake/fake_20608.jpg_0
#   inflating: data_clean/Train/Fake/fake_2848.jpg_2
#   inflating: data_clean/Train/Fake/fake_55383.jpg_0
#   inflating: data_clean/Train/Fake/fake_12982.jpg_0
#   inflating: data_clean/Train/Fake/fake_21740.jpg_0
#   inflating: data_clean/Train/Fake/fake_16837.jpg_0
#   inflating: data_clean/Train/Fake/fake_43950.jpg_0
#   inflating: data_clean/Train/Fake/fake_36723.jpg_0
#   inflating: data_clean/Train/Fake/fake_18544.jpg_0
#   inflating: data_clean/Train/Fake/fake_66676.jpg_0
#   inflating: data_clean/Train/Fake/fake_25355.jpg_1
#   inflating: data_clean/Train/Fake/fake_16505.jpg_0
#   inflating: data_clean/Train/Fake/fake_8179.jpg_0
#   inflating: data_clean/Train/Fake/fake_51381.jpg_0
#   inflating: data_clean/Train/Fake/fake_55188.jpg_3
#   inflating: data_clean/Train/Fake/fake_54552.jpg_0
#   inflating: data_clean/Train/Fake/fake_14401.jpg_0
#   inflating: data_clean/Train/Fake/fake_12757.jpg_1
#   inflating: data_clean/Train/Fake/fake_46474.jpg_0
#   inflating: data_clean/Train/Fake/fake_47221.jpg_0
#   inflating: data_clean/Train/Fake/fake_61949.jpg_0
#   inflating: data_clean/Train/Fake/fake_54663.jpg_1
#   inflating: data_clean/Train/Fake/fake_46390.jpg_0
#   inflating: data_clean/Train/Fake/fake_12437.jpg_0
#   inflating: data_clean/Train/Fake/fake_51183.jpg_0
#   inflating: data_clean/Train/Fake/fake_36031.jpg_0
#   inflating: data_clean/Train/Fake/fake_5067.jpg_1
#   inflating: data_clean/Train/Fake/fake_42400.jpg_0
#   inflating: data_clean/Train/Fake/fake_51538.jpg_2
#   inflating: data_clean/Train/Fake/fake_49169.jpg_0
#   inflating: data_clean/Train/Fake/fake_67856.jpg_1
#   inflating: data_clean/Train/Fake/fake_37314.jpg_0
#   inflating: data_clean/Train/Fake/fake_37637.jpg_0
#   inflating: data_clean/Train/Fake/fake_53018.jpg_0
#   inflating: data_clean/Train/Fake/fake_61210.jpg_0
#   inflating: data_clean/Train/Fake/fake_60174.jpg_0
#   inflating: data_clean/Train/Fake/fake_47697.jpg_0
#   inflating: data_clean/Train/Fake/fake_11468.jpg_0
#   inflating: data_clean/Train/Fake/fake_21358.jpg_0
#   inflating: data_clean/Train/Fake/fake_32922.jpg_0
#   inflating: data_clean/Train/Fake/fake_51921.jpg_0
#   inflating: data_clean/Train/Fake/fake_15806.jpg_2
#   inflating: data_clean/Train/Fake/fake_35359.jpg_0
#   inflating: data_clean/Train/Fake/fake_57088.jpg_0
#   inflating: data_clean/Train/Fake/fake_4934.jpg_0
#   inflating: data_clean/Train/Fake/fake_38222.jpg_0
#   inflating: data_clean/Train/Fake/fake_49824.jpg_0
#   inflating: data_clean/Train/Fake/fake_25577.jpg_0
#   inflating: data_clean/Train/Fake/fake_57720.jpg_1
#   inflating: data_clean/Train/Fake/fake_57766.jpg_1
#   inflating: data_clean/Train/Fake/fake_31737.jpg_0
#   inflating: data_clean/Train/Fake/fake_57214.jpg_0
#   inflating: data_clean/Train/Fake/fake_31151.jpg_2
#   inflating: data_clean/Train/Fake/fake_2665.jpg_0
#   inflating: data_clean/Train/Fake/fake_29633.jpg_0
#   inflating: data_clean/Train/Fake/fake_44202.jpg_0
#   inflating: data_clean/Train/Fake/fake_49003.jpg_1
#   inflating: data_clean/Train/Fake/fake_6207.jpg_1
#   inflating: data_clean/Train/Fake/fake_47381.jpg_0
#   inflating: data_clean/Train/Fake/fake_24394.jpg_0
#   inflating: data_clean/Train/Fake/fake_27345.jpg_0
#   inflating: data_clean/Train/Fake/fake_39780.jpg_0
#   inflating: data_clean/Train/Fake/fake_4453.jpg_0
#   inflating: data_clean/Train/Fake/fake_32612.jpg_0
#   inflating: data_clean/Train/Fake/fake_32377.jpg_1
#   inflating: data_clean/Train/Fake/fake_6039.jpg_0
#   inflating: data_clean/Train/Fake/fake_57692.jpg_1
#   inflating: data_clean/Train/Fake/fake_51684.jpg_0
#   inflating: data_clean/Train/Fake/fake_50863.jpg_0
#   inflating: data_clean/Train/Fake/fake_69434.jpg_1
#   inflating: data_clean/Train/Fake/fake_43894.jpg_0
#   inflating: data_clean/Train/Fake/fake_10967.jpg_0
#   inflating: data_clean/Train/Fake/fake_41704.jpg_0
#   inflating: data_clean/Train/Fake/fake_52337.jpg_0
#   inflating: data_clean/Train/Fake/fake_69652.jpg_0
#   inflating: data_clean/Train/Fake/fake_3382.jpg_0
#   inflating: data_clean/Train/Fake/fake_6548.jpg_0
#   inflating: data_clean/Train/Fake/fake_60422.jpg_1
#   inflating: data_clean/Train/Fake/fake_67994.jpg_0
#   inflating: data_clean/Train/Fake/fake_35027.jpg_0
#   inflating: data_clean/Train/Fake/fake_18357.jpg_0
#   inflating: data_clean/Train/Fake/fake_13410.jpg_3
#   inflating: data_clean/Train/Fake/fake_31836.jpg_0
#   inflating: data_clean/Train/Fake/fake_37153.jpg_0
#   inflating: data_clean/Train/Fake/fake_65397.jpg_1
#   inflating: data_clean/Train/Fake/fake_39763.jpg_0
#   inflating: data_clean/Train/Fake/fake_15228.jpg_0
#   inflating: data_clean/Train/Fake/fake_7847.jpg_0
#   inflating: data_clean/Train/Fake/fake_28365.jpg_0
#   inflating: data_clean/Train/Fake/fake_12468.jpg_0
#   inflating: data_clean/Train/Fake/fake_29997.jpg_0
#   inflating: data_clean/Train/Fake/fake_45141.jpg_0
#   inflating: data_clean/Train/Fake/fake_25589.jpg_0
#   inflating: data_clean/Train/Fake/fake_35990.jpg_0
#   inflating: data_clean/Train/Fake/fake_43854.jpg_0
#   inflating: data_clean/Train/Fake/fake_37611.jpg_0
#   inflating: data_clean/Train/Fake/fake_63531.jpg_0
#   inflating: data_clean/Train/Fake/fake_37054.jpg_0
#   inflating: data_clean/Train/Fake/fake_55830.jpg_0
#   inflating: data_clean/Train/Fake/fake_4719.jpg_0
#   inflating: data_clean/Train/Fake/fake_69286.jpg_0
#   inflating: data_clean/Train/Fake/fake_59947.jpg_0
#   inflating: data_clean/Train/Fake/fake_16576.jpg_1
#   inflating: data_clean/Train/Fake/fake_45465.jpg_0
#   inflating: data_clean/Train/Fake/fake_12800.jpg_0
#   inflating: data_clean/Train/Fake/fake_32476.jpg_1
#   inflating: data_clean/Train/Fake/fake_53527.jpg_0
#   inflating: data_clean/Train/Fake/fake_27241.jpg_0
#   inflating: data_clean/Train/Fake/fake_17272.jpg_1
#   inflating: data_clean/Train/Fake/fake_54003.jpg_0
#   inflating: data_clean/Train/Fake/fake_21346.jpg_0
#   inflating: data_clean/Train/Fake/fake_37329.jpg_0
#   inflating: data_clean/Train/Fake/fake_40953.jpg_0
#   inflating: data_clean/Train/Fake/fake_3940.jpg_1
#   inflating: data_clean/Train/Fake/fake_31219.jpg_0
#   inflating: data_clean/Train/Fake/fake_63414.jpg_3
#   inflating: data_clean/Train/Fake/fake_9248.jpg_0
#   inflating: data_clean/Train/Fake/fake_8250.jpg_0
#   inflating: data_clean/Train/Fake/fake_68757.jpg_0
#   inflating: data_clean/Train/Fake/fake_10496.jpg_0
#   inflating: data_clean/Train/Fake/fake_3098.jpg_0
#   inflating: data_clean/Train/Fake/fake_6605.jpg_0
#   inflating: data_clean/Train/Fake/fake_12612.jpg_0
#   inflating: data_clean/Train/Fake/fake_51872.jpg_0
#   inflating: data_clean/Train/Fake/fake_26752.jpg_0
#   inflating: data_clean/Train/Fake/fake_16943.jpg_0
#   inflating: data_clean/Train/Fake/fake_65700.jpg_0
#   inflating: data_clean/Train/Fake/fake_39504.jpg_0
#   inflating: data_clean/Train/Fake/fake_62899.jpg_1
#   inflating: data_clean/Train/Fake/fake_14479.jpg_0
#   inflating: data_clean/Train/Fake/fake_41988.jpg_1
#   inflating: data_clean/Train/Fake/fake_34723.jpg_0
#   inflating: data_clean/Train/Fake/fake_23499.jpg_1
#   inflating: data_clean/Train/Fake/fake_17289.jpg_0
#   inflating: data_clean/Train/Fake/fake_64341.jpg_0
#   inflating: data_clean/Train/Fake/fake_55938.jpg_0
#   inflating: data_clean/Train/Fake/fake_68060.jpg_1
#   inflating: data_clean/Train/Fake/fake_69878.jpg_0
#   inflating: data_clean/Train/Fake/fake_30542.jpg_0
#   inflating: data_clean/Train/Fake/fake_4476.jpg_0
#   inflating: data_clean/Train/Fake/fake_50965.jpg_0
#   inflating: data_clean/Train/Fake/fake_9236.jpg_1
#   inflating: data_clean/Train/Fake/fake_68969.jpg_1
#   inflating: data_clean/Train/Fake/fake_34496.jpg_1
#   inflating: data_clean/Train/Fake/fake_59334.jpg_0
#   inflating: data_clean/Train/Fake/fake_14221.jpg_0
#   inflating: data_clean/Train/Fake/fake_52821.jpg_0
#   inflating: data_clean/Train/Fake/fake_47232.jpg_0
#   inflating: data_clean/Train/Fake/fake_16009.jpg_0
#   inflating: data_clean/Train/Fake/fake_38421.jpg_0
#   inflating: data_clean/Train/Fake/fake_64156.jpg_1
#   inflating: data_clean/Train/Fake/fake_32231.jpg_0
#   inflating: data_clean/Train/Fake/fake_69065.jpg_1
#   inflating: data_clean/Train/Fake/fake_62362.jpg_0
#   inflating: data_clean/Train/Fake/fake_58765.jpg_0
#   inflating: data_clean/Train/Fake/fake_55263.jpg_0
#   inflating: data_clean/Train/Fake/fake_48897.jpg_0
#   inflating: data_clean/Train/Fake/fake_21539.jpg_0
#   inflating: data_clean/Train/Fake/fake_381.jpg_0
#   inflating: data_clean/Train/Fake/fake_64373.jpg_0
#   inflating: data_clean/Train/Fake/fake_64337.jpg_1
#   inflating: data_clean/Train/Fake/fake_31452.jpg_1
#   inflating: data_clean/Train/Fake/fake_17827.jpg_0
#   inflating: data_clean/Train/Fake/fake_5665.jpg_0
#   inflating: data_clean/Train/Fake/fake_27724.jpg_0
#   inflating: data_clean/Train/Fake/fake_37549.jpg_0
#   inflating: data_clean/Train/Fake/fake_25724.jpg_0
#   inflating: data_clean/Train/Fake/fake_33661.jpg_0
#   inflating: data_clean/Train/Fake/fake_18706.jpg_0
#   inflating: data_clean/Train/Fake/fake_4949.jpg_0
#   inflating: data_clean/Train/Fake/fake_20677.jpg_0
#   inflating: data_clean/Train/Fake/fake_22610.jpg_0
#   inflating: data_clean/Train/Fake/fake_4021.jpg_2
#   inflating: data_clean/Train/Fake/fake_12274.jpg_1
#   inflating: data_clean/Train/Fake/fake_43720.jpg_0
#   inflating: data_clean/Train/Fake/fake_37488.jpg_0
#   inflating: data_clean/Train/Fake/fake_64704.jpg_0
#   inflating: data_clean/Train/Fake/fake_18220.jpg_1
#   inflating: data_clean/Train/Fake/fake_56494.jpg_1
#   inflating: data_clean/Train/Fake/fake_21704.jpg_0
#   inflating: data_clean/Train/Fake/fake_53982.jpg_0
#   inflating: data_clean/Train/Fake/fake_8742.jpg_0
#   inflating: data_clean/Train/Fake/fake_69007.jpg_1
#   inflating: data_clean/Train/Fake/fake_29394.jpg_0
#   inflating: data_clean/Train/Fake/fake_55866.jpg_0
#   inflating: data_clean/Train/Fake/fake_13654.jpg_0
#   inflating: data_clean/Train/Fake/fake_4782.jpg_0
#   inflating: data_clean/Train/Fake/fake_41924.jpg_1
#   inflating: data_clean/Train/Fake/fake_53801.jpg_0
#   inflating: data_clean/Train/Fake/fake_4739.jpg_1
#   inflating: data_clean/Train/Fake/fake_9136.jpg_0
#   inflating: data_clean/Train/Fake/fake_68415.jpg_0
#   inflating: data_clean/Train/Fake/fake_56221.jpg_0
#   inflating: data_clean/Train/Fake/fake_34212.jpg_1
#   inflating: data_clean/Train/Fake/fake_34166.jpg_0
#   inflating: data_clean/Train/Fake/fake_16284.jpg_0
#   inflating: data_clean/Train/Fake/fake_17653.jpg_0
#   inflating: data_clean/Train/Fake/fake_28240.jpg_0
#   inflating: data_clean/Train/Fake/fake_19713.jpg_0
#   inflating: data_clean/Train/Fake/fake_43021.jpg_1
#   inflating: data_clean/Train/Fake/fake_4383.jpg_0
#   inflating: data_clean/Train/Fake/fake_55724.jpg_0
#   inflating: data_clean/Train/Fake/fake_2084.jpg_0
#   inflating: data_clean/Train/Fake/fake_58501.jpg_0
#   inflating: data_clean/Train/Fake/fake_69684.jpg_0
#   inflating: data_clean/Train/Fake/fake_26997.jpg_0
#   inflating: data_clean/Train/Fake/fake_43890.jpg_0
#   inflating: data_clean/Train/Fake/fake_62555.jpg_0
#   inflating: data_clean/Train/Fake/fake_57501.jpg_0
#   inflating: data_clean/Train/Fake/fake_19319.jpg_0
#   inflating: data_clean/Train/Fake/fake_9570.jpg_0
#   inflating: data_clean/Train/Fake/fake_18886.jpg_0
#   inflating: data_clean/Train/Fake/fake_30894.jpg_1
#   inflating: data_clean/Train/Fake/fake_69181.jpg_0
#   inflating: data_clean/Train/Fake/fake_3026.jpg_0
#   inflating: data_clean/Train/Fake/fake_58913.jpg_0
#   inflating: data_clean/Train/Fake/fake_53475.jpg_0
#   inflating: data_clean/Train/Fake/fake_55321.jpg_0
#   inflating: data_clean/Train/Fake/fake_10768.jpg_0
#   inflating: data_clean/Train/Fake/fake_36114.jpg_0
#   inflating: data_clean/Train/Fake/fake_5543.jpg_0
#   inflating: data_clean/Train/Fake/fake_14480.jpg_0
#   inflating: data_clean/Train/Fake/fake_15440.jpg_0
#   inflating: data_clean/Train/Fake/fake_56389.jpg_0
#   inflating: data_clean/Train/Fake/fake_47637.jpg_0
#   inflating: data_clean/Train/Fake/fake_54203.jpg_0
#   inflating: data_clean/Train/Fake/fake_26288.jpg_0
#   inflating: data_clean/Train/Fake/fake_45347.jpg_0
#   inflating: data_clean/Train/Fake/fake_37135.jpg_0
#   inflating: data_clean/Train/Fake/fake_25851.jpg_0
#   inflating: data_clean/Train/Fake/fake_69597.jpg_1
#   inflating: data_clean/Train/Fake/fake_66847.jpg_0
#   inflating: data_clean/Train/Fake/fake_63434.jpg_0
#   inflating: data_clean/Train/Fake/fake_36499.jpg_0
#   inflating: data_clean/Train/Fake/fake_3561.jpg_0
#   inflating: data_clean/Train/Fake/fake_32111.jpg_0
#   inflating: data_clean/Train/Fake/fake_2719.jpg_0
#   inflating: data_clean/Train/Fake/fake_51008.jpg_0
#   inflating: data_clean/Train/Fake/fake_60136.jpg_0
#   inflating: data_clean/Train/Fake/fake_54771.jpg_0
#   inflating: data_clean/Train/Fake/fake_31263.jpg_0
#   inflating: data_clean/Train/Fake/fake_3284.jpg_0
#   inflating: data_clean/Train/Fake/fake_13839.jpg_0
#   inflating: data_clean/Train/Fake/fake_31109.jpg_0
#   inflating: data_clean/Train/Fake/fake_68346.jpg_0
#   inflating: data_clean/Train/Fake/fake_2004.jpg_0
#   inflating: data_clean/Train/Fake/fake_23680.jpg_0
#   inflating: data_clean/Train/Fake/fake_14896.jpg_1
#   inflating: data_clean/Train/Fake/fake_62700.jpg_0
#   inflating: data_clean/Train/Fake/fake_18480.jpg_0
#   inflating: data_clean/Train/Fake/fake_40926.jpg_0
#   inflating: data_clean/Train/Fake/fake_44302.jpg_0
#   inflating: data_clean/Train/Fake/fake_43143.jpg_0
#   inflating: data_clean/Train/Fake/fake_66523.jpg_0
#   inflating: data_clean/Train/Fake/fake_57933.jpg_0
#   inflating: data_clean/Train/Fake/fake_26958.jpg_0
#   inflating: data_clean/Train/Fake/fake_14252.jpg_0
#   inflating: data_clean/Train/Fake/fake_37466.jpg_0
#   inflating: data_clean/Train/Fake/fake_50280.jpg_2
#   inflating: data_clean/Train/Fake/fake_58947.jpg_0
#   inflating: data_clean/Train/Fake/fake_43204.jpg_0
#   inflating: data_clean/Train/Fake/fake_33376.jpg_0
#   inflating: data_clean/Train/Fake/fake_10834.jpg_0
#   inflating: data_clean/Train/Fake/fake_5365.jpg_0
#   inflating: data_clean/Train/Fake/fake_35471.jpg_1
#   inflating: data_clean/Train/Fake/fake_23412.jpg_0
#   inflating: data_clean/Train/Fake/fake_66767.jpg_0
#   inflating: data_clean/Train/Fake/fake_44207.jpg_1
#   inflating: data_clean/Train/Fake/fake_39935.jpg_1
#   inflating: data_clean/Train/Fake/fake_54297.jpg_1
#   inflating: data_clean/Train/Fake/fake_31364.jpg_0
#   inflating: data_clean/Train/Fake/fake_27431.jpg_0
#   inflating: data_clean/Train/Fake/fake_35738.jpg_0
#   inflating: data_clean/Train/Fake/fake_59128.jpg_0
#   inflating: data_clean/Train/Fake/fake_60649.jpg_0
#   inflating: data_clean/Train/Fake/fake_24440.jpg_0
#   inflating: data_clean/Train/Fake/fake_29219.jpg_0
#   inflating: data_clean/Train/Fake/fake_42197.jpg_0
#   inflating: data_clean/Train/Fake/fake_27928.jpg_0
#   inflating: data_clean/Train/Fake/fake_57007.jpg_0
#   inflating: data_clean/Train/Fake/fake_59066.jpg_0
#   inflating: data_clean/Train/Fake/fake_27551.jpg_0
#   inflating: data_clean/Train/Fake/fake_66416.jpg_1
#   inflating: data_clean/Train/Fake/fake_44824.jpg_0
#   inflating: data_clean/Train/Fake/fake_46713.jpg_0
#   inflating: data_clean/Train/Fake/fake_55470.jpg_1
#   inflating: data_clean/Train/Fake/fake_51174.jpg_0
#   inflating: data_clean/Train/Fake/fake_15480.jpg_0
#   inflating: data_clean/Train/Fake/fake_54148.jpg_1
#   inflating: data_clean/Train/Fake/fake_50984.jpg_0
#   inflating: data_clean/Train/Fake/fake_20125.jpg_1
#   inflating: data_clean/Train/Fake/fake_1419.jpg_0
#   inflating: data_clean/Train/Fake/fake_15521.jpg_1
#   inflating: data_clean/Train/Fake/fake_69339.jpg_0
#   inflating: data_clean/Train/Fake/fake_49836.jpg_0
#   inflating: data_clean/Train/Fake/fake_67881.jpg_0
#   inflating: data_clean/Train/Fake/fake_37047.jpg_0
#   inflating: data_clean/Train/Fake/fake_1550.jpg_0
#   inflating: data_clean/Train/Fake/fake_45446.jpg_0
#   inflating: data_clean/Train/Fake/fake_40314.jpg_0
#   inflating: data_clean/Train/Fake/fake_62699.jpg_0
#   inflating: data_clean/Train/Fake/fake_19291.jpg_0
#   inflating: data_clean/Train/Fake/fake_44761.jpg_0
#   inflating: data_clean/Train/Fake/fake_63828.jpg_1
#   inflating: data_clean/Train/Fake/fake_27165.jpg_0
#   inflating: data_clean/Train/Fake/fake_30104.jpg_0
#   inflating: data_clean/Train/Fake/fake_66556.jpg_0
#   inflating: data_clean/Train/Fake/fake_58741.jpg_0
#   inflating: data_clean/Train/Fake/fake_65131.jpg_2
#   inflating: data_clean/Train/Fake/fake_3757.jpg_1
#   inflating: data_clean/Train/Fake/fake_3285.jpg_0
#   inflating: data_clean/Train/Fake/fake_5707.jpg_0
#   inflating: data_clean/Train/Fake/fake_14684.jpg_0
#   inflating: data_clean/Train/Fake/fake_32049.jpg_0
#   inflating: data_clean/Train/Fake/fake_7738.jpg_0
#   inflating: data_clean/Train/Fake/fake_60846.jpg_1
#   inflating: data_clean/Train/Fake/fake_35452.jpg_0
#   inflating: data_clean/Train/Fake/fake_68800.jpg_1
#   inflating: data_clean/Train/Fake/fake_52982.jpg_0
#   inflating: data_clean/Train/Fake/fake_60606.jpg_0
#   inflating: data_clean/Train/Fake/fake_30399.jpg_0
#   inflating: data_clean/Train/Fake/fake_21667.jpg_0
#   inflating: data_clean/Train/Fake/fake_16190.jpg_0
#   inflating: data_clean/Train/Fake/fake_1285.jpg_0
#   inflating: data_clean/Train/Fake/fake_60979.jpg_0
#   inflating: data_clean/Train/Fake/fake_9465.jpg_1
#   inflating: data_clean/Train/Fake/fake_53599.jpg_2
# ...
#   inflating: data_clean/Train/Fake/fake_67591.jpg_0
#   inflating: data_clean/Train/Fake/fake_43678.jpg_0
#   inflating: data_clean/Train/Fake/fake_53257.jpg_1
#   inflating: data_clean/Train/Fake/fake_54814.jpg_0
#   inflating: data_clean/Train/Fake/fake_32006.jpg_0
#   inflating: data_clean/Train/Fake/fake_5030.jpg_0
#   inflating: data_clean/Train/Fake/fake_47804.jpg_0
#   inflating: data_clean/Train/Fake/fake_42329.jpg_0
#   inflating: data_clean/Train/Fake/fake_54749.jpg_1
#   inflating: data_clean/Train/Fake/fake_12170.jpg_1
#   inflating: data_clean/Train/Fake/fake_49695.jpg_1
#   inflating: data_clean/Train/Fake/fake_35044.jpg_1
#   inflating: data_clean/Train/Fake/fake_31788.jpg_0
#   inflating: data_clean/Train/Fake/fake_11442.jpg_0
#   inflating: data_clean/Train/Fake/fake_14324.jpg_0
#   inflating: data_clean/Train/Fake/fake_68199.jpg_0
#   inflating: data_clean/Train/Fake/fake_32365.jpg_0
#   inflating: data_clean/Train/Fake/fake_59780.jpg_0
#   inflating: data_clean/Train/Fake/fake_68651.jpg_1
#   inflating: data_clean/Train/Fake/fake_1476.jpg_0
#   inflating: data_clean/Train/Fake/fake_55006.jpg_0
#   inflating: data_clean/Train/Fake/fake_42029.jpg_0
#   inflating: data_clean/Train/Fake/fake_61628.jpg_0
#   inflating: data_clean/Train/Fake/fake_20642.jpg_0
#   inflating: data_clean/Train/Fake/fake_68911.jpg_0
#   inflating: data_clean/Train/Fake/fake_61198.jpg_0
#   inflating: data_clean/Train/Fake/fake_68035.jpg_1
#   inflating: data_clean/Train/Fake/fake_1747.jpg_0
#   inflating: data_clean/Train/Fake/fake_1484.jpg_0
#   inflating: data_clean/Train/Fake/fake_2888.jpg_0
#   inflating: data_clean/Train/Fake/fake_20035.jpg_1
#   inflating: data_clean/Train/Fake/fake_55537.jpg_0
#   inflating: data_clean/Train/Fake/fake_35714.jpg_1
#   inflating: data_clean/Train/Fake/fake_11068.jpg_0
#   inflating: data_clean/Train/Fake/fake_53860.jpg_0
#   inflating: data_clean/Train/Fake/fake_60149.jpg_0
#   inflating: data_clean/Train/Fake/fake_53798.jpg_0
#   inflating: data_clean/Train/Fake/fake_16034.jpg_0
#   inflating: data_clean/Train/Fake/fake_35531.jpg_0
#   inflating: data_clean/Train/Fake/fake_19722.jpg_0
#   inflating: data_clean/Train/Fake/fake_11741.jpg_0
#   inflating: data_clean/Train/Fake/fake_17124.jpg_0
#   inflating: data_clean/Train/Fake/fake_16066.jpg_0
#   inflating: data_clean/Train/Fake/fake_68796.jpg_0
#   inflating: data_clean/Train/Fake/fake_17154.jpg_1
#   inflating: data_clean/Train/Fake/fake_544.jpg_0
#   inflating: data_clean/Train/Fake/fake_12811.jpg_0
#   inflating: data_clean/Train/Fake/fake_35001.jpg_1
#   inflating: data_clean/Train/Fake/fake_33621.jpg_0
#   inflating: data_clean/Train/Fake/fake_605.jpg_1
#   inflating: data_clean/Train/Fake/fake_28113.jpg_1
#   inflating: data_clean/Train/Fake/fake_31108.jpg_1
#   inflating: data_clean/Train/Fake/fake_2672.jpg_0
#   inflating: data_clean/Train/Fake/fake_43667.jpg_0
#   inflating: data_clean/Train/Fake/fake_15466.jpg_0
#   inflating: data_clean/Train/Fake/fake_57081.jpg_1
#   inflating: data_clean/Train/Fake/fake_15322.jpg_0
#   inflating: data_clean/Train/Fake/fake_65449.jpg_0
#   inflating: data_clean/Train/Fake/fake_7784.jpg_0
#   inflating: data_clean/Train/Fake/fake_51972.jpg_2
#   inflating: data_clean/Train/Fake/fake_53480.jpg_0
#   inflating: data_clean/Train/Fake/fake_56610.jpg_0
#   inflating: data_clean/Train/Fake/fake_33154.jpg_2
#   inflating: data_clean/Train/Fake/fake_587.jpg_0
#   inflating: data_clean/Train/Fake/fake_7875.jpg_0
#   inflating: data_clean/Train/Fake/fake_55446.jpg_0
#   inflating: data_clean/Train/Fake/fake_15404.jpg_0
#   inflating: data_clean/Train/Fake/fake_63644.jpg_0
#   inflating: data_clean/Train/Fake/fake_11296.jpg_0
#   inflating: data_clean/Train/Fake/fake_33375.jpg_0
#   inflating: data_clean/Train/Fake/fake_35253.jpg_1
#   inflating: data_clean/Train/Fake/fake_22509.jpg_0
#   inflating: data_clean/Train/Fake/fake_61442.jpg_0
#   inflating: data_clean/Train/Fake/fake_33725.jpg_0
#   inflating: data_clean/Train/Fake/fake_27447.jpg_1
#   inflating: data_clean/Train/Fake/fake_26054.jpg_0
#   inflating: data_clean/Train/Fake/fake_3731.jpg_0
#   inflating: data_clean/Train/Fake/fake_23874.jpg_0
#   inflating: data_clean/Train/Fake/fake_20973.jpg_0
#   inflating: data_clean/Train/Fake/fake_55822.jpg_0
#   inflating: data_clean/Train/Fake/fake_12237.jpg_1
#   inflating: data_clean/Train/Fake/fake_19149.jpg_0
#   inflating: data_clean/Train/Fake/fake_1601.jpg_0
#   inflating: data_clean/Train/Fake/fake_36235.jpg_0
#   inflating: data_clean/Train/Fake/fake_50374.jpg_0
#   inflating: data_clean/Train/Fake/fake_64250.jpg_0
#   inflating: data_clean/Train/Fake/fake_31391.jpg_0
#   inflating: data_clean/Train/Fake/fake_47356.jpg_0
#   inflating: data_clean/Train/Fake/fake_10635.jpg_0
#   inflating: data_clean/Train/Fake/fake_31640.jpg_0
#   inflating: data_clean/Train/Fake/fake_55041.jpg_0
#   inflating: data_clean/Train/Fake/fake_50560.jpg_1
#   inflating: data_clean/Train/Fake/fake_42937.jpg_0
#   inflating: data_clean/Train/Fake/fake_59444.jpg_0
#   inflating: data_clean/Train/Fake/fake_56898.jpg_1
#   inflating: data_clean/Train/Fake/fake_58928.jpg_0
#   inflating: data_clean/Train/Fake/fake_37423.jpg_0
#   inflating: data_clean/Train/Fake/fake_57079.jpg_1
#   inflating: data_clean/Train/Fake/fake_64545.jpg_1
#   inflating: data_clean/Train/Fake/fake_41798.jpg_0
#   inflating: data_clean/Train/Fake/fake_33280.jpg_0
#   inflating: data_clean/Train/Fake/fake_53774.jpg_0
#   inflating: data_clean/Train/Fake/fake_56017.jpg_0
#   inflating: data_clean/Train/Fake/fake_8380.jpg_0
#   inflating: data_clean/Train/Fake/fake_20146.jpg_0
#   inflating: data_clean/Train/Fake/fake_1157.jpg_1
#   inflating: data_clean/Train/Fake/fake_24861.jpg_0
#   inflating: data_clean/Train/Fake/fake_40353.jpg_0
#   inflating: data_clean/Train/Fake/fake_31800.jpg_0
#   inflating: data_clean/Train/Fake/fake_19693.jpg_0
#   inflating: data_clean/Train/Fake/fake_15314.jpg_1
#   inflating: data_clean/Train/Fake/fake_32525.jpg_0
#   inflating: data_clean/Train/Fake/fake_3812.jpg_0
#   inflating: data_clean/Train/Fake/fake_43573.jpg_0
#   inflating: data_clean/Train/Fake/fake_26750.jpg_0
#   inflating: data_clean/Train/Fake/fake_153.jpg_0
#   inflating: data_clean/Train/Fake/fake_8212.jpg_0
#   inflating: data_clean/Train/Fake/fake_69182.jpg_0
#   inflating: data_clean/Train/Fake/fake_7117.jpg_0
#   inflating: data_clean/Train/Fake/fake_36936.jpg_0
#   inflating: data_clean/Train/Fake/fake_61447.jpg_0
#   inflating: data_clean/Train/Fake/fake_13073.jpg_2
#   inflating: data_clean/Train/Fake/fake_4174.jpg_0
#   inflating: data_clean/Train/Fake/fake_42079.jpg_0
#   inflating: data_clean/Train/Fake/fake_45774.jpg_0
#   inflating: data_clean/Train/Fake/fake_41915.jpg_0
#   inflating: data_clean/Train/Fake/fake_49364.jpg_0
#   inflating: data_clean/Train/Fake/fake_56577.jpg_0
#   inflating: data_clean/Train/Fake/fake_25944.jpg_0
#   inflating: data_clean/Train/Fake/fake_52487.jpg_0
#   inflating: data_clean/Train/Fake/fake_65037.jpg_0
#   inflating: data_clean/Train/Fake/fake_69302.jpg_0
#   inflating: data_clean/Train/Fake/fake_53908.jpg_0
#   inflating: data_clean/Train/Fake/fake_49122.jpg_0
#   inflating: data_clean/Train/Fake/fake_7568.jpg_0
#   inflating: data_clean/Train/Fake/fake_51571.jpg_1
#   inflating: data_clean/Train/Fake/fake_15069.jpg_0
#   inflating: data_clean/Train/Fake/fake_63582.jpg_0
#   inflating: data_clean/Train/Fake/fake_53101.jpg_0
#   inflating: data_clean/Train/Fake/fake_61018.jpg_0
#   inflating: data_clean/Train/Fake/fake_40642.jpg_0
#   inflating: data_clean/Train/Fake/fake_54121.jpg_1
#   inflating: data_clean/Train/Fake/fake_47698.jpg_0
#   inflating: data_clean/Train/Fake/fake_12623.jpg_0
#   inflating: data_clean/Train/Fake/fake_45259.jpg_0
#   inflating: data_clean/Train/Fake/fake_22721.jpg_0
#   inflating: data_clean/Train/Fake/fake_59579.jpg_0
#   inflating: data_clean/Train/Fake/fake_58029.jpg_0
#   inflating: data_clean/Train/Fake/fake_8946.jpg_0
#   inflating: data_clean/Train/Fake/fake_54582.jpg_0
#   inflating: data_clean/Train/Fake/fake_41274.jpg_0
#   inflating: data_clean/Train/Fake/fake_58489.jpg_0
#   inflating: data_clean/Train/Fake/fake_30383.jpg_0
#   inflating: data_clean/Train/Fake/fake_59803.jpg_0
#   inflating: data_clean/Train/Fake/fake_62314.jpg_1
#   inflating: data_clean/Train/Fake/fake_15537.jpg_1
#   inflating: data_clean/Train/Fake/fake_65092.jpg_1
#   inflating: data_clean/Train/Fake/fake_62701.jpg_0
#   inflating: data_clean/Train/Fake/fake_61207.jpg_0
#   inflating: data_clean/Train/Fake/fake_25619.jpg_0
#   inflating: data_clean/Train/Fake/fake_29723.jpg_4
#   inflating: data_clean/Train/Fake/fake_67424.jpg_0
#   inflating: data_clean/Train/Fake/fake_42876.jpg_1
#   inflating: data_clean/Train/Fake/fake_5652.jpg_0
#   inflating: data_clean/Train/Fake/fake_3720.jpg_1
#   inflating: data_clean/Train/Fake/fake_35011.jpg_0
#   inflating: data_clean/Train/Fake/fake_38630.jpg_1
#   inflating: data_clean/Train/Fake/fake_69630.jpg_2
#   inflating: data_clean/Train/Fake/fake_58767.jpg_1
#   inflating: data_clean/Train/Fake/fake_12243.jpg_0
#   inflating: data_clean/Train/Fake/fake_57934.jpg_0
#   inflating: data_clean/Train/Fake/fake_67879.jpg_0
#   inflating: data_clean/Train/Fake/fake_324.jpg_0
#   inflating: data_clean/Train/Fake/fake_48560.jpg_1
#   inflating: data_clean/Train/Fake/fake_39569.jpg_0
#   inflating: data_clean/Train/Fake/fake_20116.jpg_0
#   inflating: data_clean/Train/Fake/fake_8063.jpg_0
#   inflating: data_clean/Train/Fake/fake_46565.jpg_0
#   inflating: data_clean/Train/Fake/fake_33478.jpg_0
#   inflating: data_clean/Train/Fake/fake_29559.jpg_1
#   inflating: data_clean/Train/Fake/fake_2915.jpg_0
#   inflating: data_clean/Train/Fake/fake_65717.jpg_0
#   inflating: data_clean/Train/Fake/fake_62370.jpg_0
#   inflating: data_clean/Train/Fake/fake_20521.jpg_1
#   inflating: data_clean/Train/Fake/fake_32833.jpg_0
#   inflating: data_clean/Train/Fake/fake_45679.jpg_0
#   inflating: data_clean/Train/Fake/fake_44980.jpg_0
#   inflating: data_clean/Train/Fake/fake_58749.jpg_0
#   inflating: data_clean/Train/Fake/fake_17479.jpg_2
#   inflating: data_clean/Train/Fake/fake_33816.jpg_0
#   inflating: data_clean/Train/Fake/fake_5183.jpg_1
#   inflating: data_clean/Train/Fake/fake_44326.jpg_0
#   inflating: data_clean/Train/Fake/fake_67694.jpg_0
#   inflating: data_clean/Train/Fake/fake_68284.jpg_0
#   inflating: data_clean/Train/Fake/fake_18810.jpg_0
#   inflating: data_clean/Train/Fake/fake_14206.jpg_0
#   inflating: data_clean/Train/Fake/fake_63860.jpg_0
#   inflating: data_clean/Train/Fake/fake_11218.jpg_0
#   inflating: data_clean/Train/Fake/fake_34671.jpg_2
#   inflating: data_clean/Train/Fake/fake_17556.jpg_0
#   inflating: data_clean/Train/Fake/fake_32199.jpg_0
#   inflating: data_clean/Train/Fake/fake_54268.jpg_0
#   inflating: data_clean/Train/Fake/fake_24746.jpg_0
#   inflating: data_clean/Train/Fake/fake_48943.jpg_0
#   inflating: data_clean/Train/Fake/fake_7146.jpg_0
#   inflating: data_clean/Train/Fake/fake_53508.jpg_1
#   inflating: data_clean/Train/Fake/fake_43563.jpg_0
#   inflating: data_clean/Train/Fake/fake_40282.jpg_0
#   inflating: data_clean/Train/Fake/fake_9472.jpg_0
#   inflating: data_clean/Train/Fake/fake_11403.jpg_0
#   inflating: data_clean/Train/Fake/fake_2737.jpg_0
#   inflating: data_clean/Train/Fake/fake_23499.jpg_0
#   inflating: data_clean/Train/Fake/fake_48879.jpg_1
#   inflating: data_clean/Train/Fake/fake_55718.jpg_0
#   inflating: data_clean/Train/Fake/fake_7278.jpg_0
#   inflating: data_clean/Train/Fake/fake_51992.jpg_0
#   inflating: data_clean/Train/Fake/fake_62132.jpg_0
#   inflating: data_clean/Train/Fake/fake_54044.jpg_0
#   inflating: data_clean/Train/Fake/fake_26530.jpg_0
#   inflating: data_clean/Train/Fake/fake_23907.jpg_0
#   inflating: data_clean/Train/Fake/fake_32116.jpg_0
#   inflating: data_clean/Train/Fake/fake_13422.jpg_2
#   inflating: data_clean/Train/Fake/fake_40511.jpg_0
#   inflating: data_clean/Train/Fake/fake_11956.jpg_0
#   inflating: data_clean/Train/Fake/fake_46088.jpg_0
#   inflating: data_clean/Train/Fake/fake_67455.jpg_0
#   inflating: data_clean/Train/Fake/fake_66027.jpg_0
#   inflating: data_clean/Train/Fake/fake_56497.jpg_0
#   inflating: data_clean/Train/Fake/fake_23986.jpg_0
#   inflating: data_clean/Train/Fake/fake_27524.jpg_0
#   inflating: data_clean/Train/Fake/fake_45167.jpg_0
#   inflating: data_clean/Train/Fake/fake_26564.jpg_0
#   inflating: data_clean/Train/Fake/fake_10165.jpg_0
#   inflating: data_clean/Train/Fake/fake_8866.jpg_0
#   inflating: data_clean/Train/Fake/fake_14024.jpg_0
#   inflating: data_clean/Train/Fake/fake_18700.jpg_0
#   inflating: data_clean/Train/Fake/fake_58525.jpg_0
#   inflating: data_clean/Train/Fake/fake_1591.jpg_0
#   inflating: data_clean/Train/Fake/fake_39559.jpg_0
#   inflating: data_clean/Train/Fake/fake_31704.jpg_3
#   inflating: data_clean/Train/Fake/fake_46731.jpg_0
#   inflating: data_clean/Train/Fake/fake_17832.jpg_0
#   inflating: data_clean/Train/Fake/fake_39570.jpg_0
#   inflating: data_clean/Train/Fake/fake_50992.jpg_0
#   inflating: data_clean/Train/Fake/fake_12592.jpg_0
#   inflating: data_clean/Train/Fake/fake_48372.jpg_0
#   inflating: data_clean/Train/Fake/fake_32103.jpg_1
#   inflating: data_clean/Train/Fake/fake_54067.jpg_1
#   inflating: data_clean/Train/Fake/fake_64563.jpg_0
#   inflating: data_clean/Train/Fake/fake_25089.jpg_0
#   inflating: data_clean/Train/Fake/fake_42201.jpg_0
#   inflating: data_clean/Train/Fake/fake_43508.jpg_0
#   inflating: data_clean/Train/Fake/fake_68917.jpg_0
#   inflating: data_clean/Train/Fake/fake_53728.jpg_1
#   inflating: data_clean/Train/Fake/fake_38315.jpg_0
#   inflating: data_clean/Train/Fake/fake_54491.jpg_0
#   inflating: data_clean/Train/Fake/fake_39321.jpg_0
#   inflating: data_clean/Train/Fake/fake_59715.jpg_0
#   inflating: data_clean/Train/Fake/fake_16955.jpg_0
#   inflating: data_clean/Train/Fake/fake_32790.jpg_0
#   inflating: data_clean/Train/Fake/fake_53616.jpg_0
#   inflating: data_clean/Train/Fake/fake_31892.jpg_0
#   inflating: data_clean/Train/Fake/fake_29901.jpg_0
#   inflating: data_clean/Train/Fake/fake_53614.jpg_0
#   inflating: data_clean/Train/Fake/fake_28034.jpg_0
#   inflating: data_clean/Train/Fake/fake_62191.jpg_0
#   inflating: data_clean/Train/Fake/fake_12823.jpg_0
#   inflating: data_clean/Train/Fake/fake_44539.jpg_0
#   inflating: data_clean/Train/Fake/fake_7966.jpg_0
#   inflating: data_clean/Train/Fake/fake_19507.jpg_1
#   inflating: data_clean/Train/Fake/fake_60308.jpg_0
#   inflating: data_clean/Train/Fake/fake_36856.jpg_0
#   inflating: data_clean/Train/Fake/fake_44563.jpg_0
#   inflating: data_clean/Train/Fake/fake_64767.jpg_0
#   inflating: data_clean/Train/Fake/fake_61705.jpg_0
#   inflating: data_clean/Train/Fake/fake_65162.jpg_2
#   inflating: data_clean/Train/Fake/fake_65051.jpg_0
#   inflating: data_clean/Train/Fake/fake_30692.jpg_0
#   inflating: data_clean/Train/Fake/fake_9663.jpg_0
#   inflating: data_clean/Train/Fake/fake_50775.jpg_1
#   inflating: data_clean/Train/Fake/fake_66104.jpg_0
#   inflating: data_clean/Train/Fake/fake_42938.jpg_0
#   inflating: data_clean/Train/Fake/fake_61463.jpg_0
#   inflating: data_clean/Train/Fake/fake_35088.jpg_0
#   inflating: data_clean/Train/Fake/fake_8903.jpg_0
#   inflating: data_clean/Train/Fake/fake_35094.jpg_0
#   inflating: data_clean/Train/Fake/fake_65624.jpg_0
#   inflating: data_clean/Train/Fake/fake_56595.jpg_0
#   inflating: data_clean/Train/Fake/fake_53524.jpg_2
#   inflating: data_clean/Train/Fake/fake_6457.jpg_0
#   inflating: data_clean/Train/Fake/fake_68326.jpg_0
#   inflating: data_clean/Train/Fake/fake_62642.jpg_0
#   inflating: data_clean/Train/Fake/fake_41912.jpg_0
#   inflating: data_clean/Train/Fake/fake_60911.jpg_0
#   inflating: data_clean/Train/Fake/fake_12317.jpg_0
#   inflating: data_clean/Train/Fake/fake_14911.jpg_0
#   inflating: data_clean/Train/Fake/fake_17970.jpg_1

# %% [markdown]
# ## Setup GPU

# %%
# Set device to GPU if available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print("Device:", device)
# Out:
# Device: cuda

# %% [markdown]
# # Datasets

# %%
class Dataset(Dataset):
  def __init__(
              self,
              root_dir,
              transform=None,
              split: Literal["train", "val", "test"] = "train",
              ):
    self.transform = transform
    self.split = split

    if self.split == "train":
      self.root_dir = os.path.join(root_dir, "Train")
    if self.split == "val":
      self.root_dir = os.path.join(root_dir, "Validation")
    if self.split == "test":
      self.root_dir = os.path.join(root_dir, "Test")

    self.classes = sorted(os.listdir(self.root_dir))
    self.class_to_idx = {cls: i for i, cls in enumerate(self.classes)}

    self.samples = []

    for cls in self.classes:
      cls_dir = os.path.join(self.root_dir, cls)

      for file in os.listdir(cls_dir):
        path = os.path.join(cls_dir, file)
        label = self.class_to_idx[cls]

        self.samples.append({
            "path": path,
            "label": label,
        })

  def __getitem__(self, idx):
    img_path = self.samples[idx]["path"]
    label = self.samples[idx]["label"]

    image = Image.open(img_path).convert("RGB")

    if self.transform:
      image = self.transform(image)

    return image, label

  def __len__(self):
    return len(self.samples)

# %% [markdown]
# # Transforms

# %%
# Find size of largest image
root_dir = "/content/data_clean"

widths = []
heights = []

total_files = 0
for root, dirs, files in os.walk(root_dir):
  total_files += len(files)

with tqdm(total = total_files, desc="Checking sizes") as pbar:
  for root, dirs, files in os.walk(root_dir):
    for f in files:
      with Image.open(os.path.join(root, f)) as img:
        width, height = img.size

        widths.append(width)
        heights.append(height)

      pbar.update(1)

print("Max width:", max(widths))
print("Max height:", max(heights))
print()
print("Min width:", min(widths))
print("Min height:", min(heights))
print()
print("Mean width:", statistics.mean(widths))
print("Mean height:", statistics.mean(heights))
print()
print("Median width:", statistics.median(widths))
print("Median height:", statistics.median(heights))
# Out:
# Checking sizes:   0%|          | 0/251599 [00:00<?, ?it/s]
# Max width: 255
# Max height: 255
#
# Min width: 1
# Min height: 1
#
# Mean width: 92.46743826485798
# Mean height: 126.93190354492666
#
# Median width: 94
# Median height: 128

# %%
sns.histplot(data=widths)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data=heights)
# Out:
# <Axes: ylabel='Count'>

# %%
class PadToSize:
    def __init__(self, target_size, fill=0):
        self.target_h, self.target_w = target_size
        self.fill = fill

    def __call__(self, img):
        w, h = img.size  # PIL: (width, height)

        pad_h = max(self.target_h - h, 0)
        pad_w = max(self.target_w - w, 0)

        # Split padding evenly (center the image)
        padding = (
            pad_w // 2,                    # left
            pad_h // 2,                    # top
            pad_w - pad_w // 2,            # right
            pad_h - pad_h // 2             # bottom
        )

        return F.pad(img, padding, fill=self.fill)

# %%
img_size = 150

# Base transforms for val, test, and inference
base_transforms = T.Compose([
  T.Resize(size=None, max_size=img_size),

  PadToSize((img_size, img_size)),

  T.ToImage(),
  T.ToDtype(torch.float32, scale=True),

  T.Normalize(
    mean=[0.485, 0.456, 0.406],
    std=[0.229, 0.224, 0.225]
  )
])

# Aug transforms for train
aug_transforms = T.Compose([
  T.Resize(size=None, max_size=img_size),

  PadToSize((img_size, img_size)),

  T.RandomHorizontalFlip(p=0.5),

  T.ColorJitter(
    brightness=0.2,
    contrast=0.2,
    saturation=0.2
  ),

  T.ToImage(),
  T.ToDtype(torch.float32, scale=True),

  T.Normalize(
      mean=[0.485, 0.456, 0.406],
      std=[0.229, 0.224, 0.225]
  )
])

# %% [markdown]
# # Training Model

# %% [markdown]
# ## Config

# %%
# Config

# Subset
train_on_subset = False
subset_size_proportion = 0.01

# Training
num_epochs = 20
batch_size = 128
num_workers = 2
patience = 3 # Stop if no improvement after
min_delta = 0.005 # Amt decrease in loss needed for action

# Optimizer
learning_rate = 0.0001
betas = (0.9, 0.990)
weight_decay = 0.0005

# Learning rate scheduler
step_size = 7
gamma = 0.1

# Saves
best_model_filepath = "/content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/best_model"
checkpoint_filepath = "/content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints"

# %% [markdown]
# ## DataLoaders

# %%
# Load datasets for train, val, and test
train_dataset = Dataset(
    root_dir="/content/data_clean/",
    transform=aug_transforms,
    split="train",
)

val_dataset = Dataset(
    root_dir="/content/data_clean/",
    transform=base_transforms,
    split="val",
)

test_dataset = Dataset(
    root_dir="/content/data_clean/",
    transform=base_transforms,
    split="test",
)

# Print classes
print("Class IDs train:", train_dataset.class_to_idx)
print("Class IDs val:", val_dataset.class_to_idx)
print("Class IDs test:", test_dataset.class_to_idx)

if train_on_subset:
  from torch.utils.data import Subset

  train_n = min(int(len(train_dataset) * subset_size_proportion), len(train_dataset))
  val_n   = min(int(len(val_dataset) * subset_size_proportion), len(val_dataset))
  test_n  = min(int(len(test_dataset) * subset_size_proportion), len(test_dataset))

  train_indices = torch.randperm(len(train_dataset))[:train_n]
  val_indices   = torch.randperm(len(val_dataset))[:val_n]
  test_indices  = torch.randperm(len(test_dataset))[:test_n]

  train_dataset = Subset(train_dataset, train_indices)
  val_dataset   = Subset(val_dataset, val_indices)
  test_dataset  = Subset(test_dataset, test_indices)

# Print datasets sizes
print("Train dataset size", len(train_dataset))
print("Val dataset size", len(val_dataset))
print("Test dataset size", len(test_dataset))
# Out:
# Class IDs train: {'Fake': 0, 'Real': 1}
# Class IDs val: {'Fake': 0, 'Real': 1}
# Class IDs test: {'Fake': 0, 'Real': 1}
# Train dataset size 182926
# Val dataset size 54573
# Test dataset size 14100

# %%
# Create dataloaders
train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
    pin_memory=True,
    )

val_datloader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers,
    pin_memory=True,
    )

test_dataloader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers,
    pin_memory=True,
    )

# %% [markdown]
# ## Model

# %%
class DeepFakeDetector(nn.Module):
  def __init__(self):
    super().__init__()

    backbone = models.resnet50(pretrained=False)

    self.features = nn.Sequential(*list(backbone.children())[:-1])

    self.classifier = nn.Sequential(
      nn.Linear(2048, 512),
      nn.ReLU(),
      nn.Dropout(0.5),
      nn.Linear(512, 1)
    )

  def forward(self, x):
    x = self.features(x)
    x = torch.flatten(x, 1)
    x = self.classifier(x)
    return x

# %% [markdown]
# ## Training Setup

# %%
model = DeepFakeDetector()

criterion = nn.BCEWithLogitsLoss()

optimizer = torch.optim.AdamW(
    params=model.parameters(),
    lr=learning_rate,
    betas=betas,
    weight_decay=weight_decay
    )

lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer=optimizer,
    step_size=step_size,
    gamma=gamma
    )
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %% [markdown]
# ## Training Loop

# %%
# Saves model
def save_model(model, filepath="/content/", model_name="model"):
  torch.save(model.state_dict(), f"{filepath}/{model_name}_state_dict.pth") # Saves state dict
  torch.save(model, f"{filepath}/{model_name}.pth") # Saves entire model
  print("Model saved!")

# %%
def save_checkpoint(epoch, model_state_dict, optimizer_state_dict, loss, results, filepath):
    state = {
        'epoch': epoch,
        'model_state_dict': model_state_dict,
        'optimizer_state_dict': optimizer_state_dict,
        'loss': loss,
        'results': results,
    }
    torch.save(state, filepath)
    print(f"Checkpoint saved to {filepath}")

# %%
def validate(model, dataloader, loss_function, epoch, num_epochs):
  model.eval()

  total_loss = 0.0
  total_correct = 0
  total_samples = 0

  with torch.no_grad():
    pbar = tqdm(
              dataloader,
              desc=f"Epoch {epoch+1}/{num_epochs} [Validation]",
              leave=True,
              dynamic_ncols=True
              )
    for images, labels in pbar:
      images = images.to(device)
      labels = labels.to(device).float().unsqueeze(1)

      outputs = model(images)
      loss = loss_function(outputs, labels)
      total_loss += loss.item() * len(images)
      pred_labels = (outputs >= 0)
      total_correct += (pred_labels == labels).sum().item()
      total_samples += labels.size(0)

      avg_loss = total_loss / total_samples
      avg_acc = total_correct / total_samples

      pbar.set_postfix({"loss": f"{avg_loss:.4f}", "acc": f"{avg_acc:.4f}"})

  return avg_loss, avg_acc

# %%
def train_one_epoch(model, dataloader, optimizer, loss_function, lr_scheduler, device, epoch, num_epochs):
  model.train()

  total_loss = 0.0
  total_correct = 0
  total_samples = 0

  pbar = tqdm(
              dataloader,
              desc=f"Epoch {epoch+1}/{num_epochs} [Train]",
              leave=True,
              dynamic_ncols=True
              )
  for images, labels in pbar:
    images = images.to(device)
    labels = labels.to(device).float().unsqueeze(1)

    # Forward pass
    outputs = model(images)
    loss = loss_function(outputs, labels)

    total_loss += loss.item() * len(images)
    pred_labels = (outputs >= 0)
    total_correct += (pred_labels == labels).sum().item()
    total_samples += labels.size(0)

    avg_loss = total_loss / total_samples
    avg_acc = total_correct / total_samples

    pbar.set_postfix({"loss": f"{avg_loss:.4f}", "acc": f"{avg_acc:.4f}"})

    optimizer.zero_grad()

    # Backward pass
    loss.backward()

    optimizer.step()

  lr_scheduler.step()

  return avg_loss, avg_acc

# %%
def test(model, dataloader, loss_function):
  model.eval()

  total_loss = 0.0
  total_correct = 0
  total_samples = 0

  with torch.no_grad():
    pbar = tqdm(
              dataloader,
              desc="[Test]",
              leave=True,
              dynamic_ncols=True
              )
    for images, labels in pbar:
      images = images.to(device)
      labels = labels.to(device).float().unsqueeze(1)

      outputs = model(images)
      loss = loss_function(outputs, labels)
      total_loss += loss.item() * len(images)
      pred_labels = (outputs >= 0)
      total_correct += (pred_labels == labels).sum().item()
      total_samples += labels.size(0)

      avg_loss = total_loss / total_samples
      avg_acc = total_correct / total_samples

      pbar.set_postfix({"loss": f"{avg_loss:.4f}", "acc": f"{avg_acc:.4f}"})

  return avg_loss, avg_acc

# %%
def train(model, train_loader, val_loader, optimizer, loss_function, lr_scheduler, device, num_epochs):
  train_losses = []
  train_accs = []
  val_losses = []
  val_accs = []
  best_val_loss = float("inf")
  last_model_saved_epoch = 0
  epochs_no_improve = 0

  model.to(device) # Move model to device

  for epoch in range(num_epochs):
    # ----TRAIN----
    train_loss, train_acc = train_one_epoch(
        model=model,
        dataloader=train_loader,
        optimizer=optimizer,
        loss_function=loss_function,
        lr_scheduler=lr_scheduler,
        device=device,
        epoch=epoch,
        num_epochs=num_epochs,
    )
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # ----VAL----
    val_loss, val_acc = validate(
        model=model,
        dataloader=val_loader,
        loss_function=loss_function,
        epoch=epoch,
        num_epochs=num_epochs)
    val_losses.append(val_loss)
    val_accs.append(val_acc)

    print(f"Epoch {epoch+1}/{num_epochs} | Train loss: {train_loss:.4f} | Train acc: {train_acc:.4f} | Val loss: {val_loss:.4f} | Val acc: {val_acc:.4f}")

    save_checkpoint(
        epoch=epoch + 1,
        model_state_dict=model.state_dict(),
        optimizer_state_dict=optimizer.state_dict(),
        loss=val_loss,
        results=val_acc,
        filepath=f"{checkpoint_filepath}/save_checkpoint_{epoch + 1}.pth")

    # Model save if better than before
    if val_loss < best_val_loss - min_delta:
      best_val_loss = val_loss
      epochs_no_improve = 0
      save_model(model, filepath=best_model_filepath)
      last_model_saved_epoch = epoch + 1
    else: # Early stopping if no improvements
      epochs_no_improve += 1
      if epochs_no_improve >= patience:
        print(f"Training stopped early at epoch {epoch + 1}")
        break
      else:
        print(f"No improvement, early stopping may happen after {patience - epochs_no_improve} more epochs if no improvements")

  # ----TEST----
  test_loss, test_acc = test(
      model=model,
      dataloader=val_loader,
      loss_function=loss_function)
  print(f"Test loss: {test_loss} | Test acc: {test_acc}")

  history = {
      "train_losses": train_losses,
      "train_accs": train_accs,
      "val_losses": val_losses,
      "val_accs": val_accs,
      "last_model_saved_epoch": last_model_saved_epoch,
      "test_loss": test_loss,
      "test_acc": test_acc
  }

  return history

# %% [markdown]
# ## Plotting

# %%
# Plots training and validation losses
def plot_loss(training_losses: List[float], val_losses: List[float], last_model_saved_epoch: int):
  sns.lineplot(x=range(1, len(training_losses) + 1), y=training_losses, label="Training Loss")
  sns.lineplot(x=range(1, len(val_losses) + 1), y=val_losses, label="Validation Loss")

  plt.xticks(range(1, len(val_losses) + 1))
  plt.axvline(x=last_model_saved_epoch, color='r', linestyle='--', label='Last model saved')
  plt.legend()
  plt.show()

# %%
# Plots training and validation losses
def plot_acc(training_accs: List[float], val_accs: List[float], last_model_saved_epoch: int):
  sns.lineplot(x=range(1, len(training_accs) + 1), y=training_accs, label="Training Loss")
  sns.lineplot(x=range(1, len(val_accs) + 1), y=val_accs, label="Validation Loss")

  plt.xticks(range(1, len(val_accs) + 1))
  plt.axvline(x=last_model_saved_epoch, color='r', linestyle='--', label='Last model saved')
  plt.legend()
  plt.show()

# %% [markdown]
# ## Run Training & Show Metrics

# %%
history = train(
    model=model,
    train_loader=train_dataloader,
    val_loader=val_datloader,
    optimizer=optimizer,
    loss_function=criterion,
    lr_scheduler=lr_scheduler,
    device=device,
    num_epochs=num_epochs
    )
# Out:
# Epoch 1/20 [Train]:   0%|          | 0/1430 [00:00<?, ?it/s]
# Epoch 1/20 [Validation]:   0%|          | 0/427 [00:00<?, ?it/s]
# Epoch 1/20 | Train loss: 0.5094 | Train acc: 0.7298 | Val loss: 0.5290 | Val acc: 0.7595
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_1.pth
# Model saved!
# Epoch 2/20 [Train]:   0%|          | 0/1430 [00:00<?, ?it/s]
# Epoch 2/20 [Validation]:   0%|          | 0/427 [00:00<?, ?it/s]
# Epoch 2/20 | Train loss: 0.3249 | Train acc: 0.8574 | Val loss: 0.4036 | Val acc: 0.8010
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_2.pth
# Model saved!
# Epoch 3/20 [Train]:   0%|          | 0/1430 [00:00<?, ?it/s]
# Epoch 3/20 [Validation]:   0%|          | 0/427 [00:00<?, ?it/s]
# Epoch 3/20 | Train loss: 0.2838 | Train acc: 0.8764 | Val loss: 0.3232 | Val acc: 0.8577
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_3.pth
# Model saved!
# Epoch 4/20 [Train]:   0%|          | 0/1430 [00:00<?, ?it/s]
# Epoch 4/20 [Validation]:   0%|          | 0/427 [00:00<?, ?it/s]
# Epoch 4/20 | Train loss: 0.2602 | Train acc: 0.8874 | Val loss: 0.3614 | Val acc: 0.8480
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_4.pth
# No improvement, early stopping may happen after 2 more epochs if no improvements
# Epoch 5/20 [Train]:   0%|          | 0/1430 [00:00<?, ?it/s]
# Epoch 5/20 [Validation]:   0%|          | 0/427 [00:00<?, ?it/s]
# Epoch 5/20 | Train loss: 0.2466 | Train acc: 0.8927 | Val loss: 0.3330 | Val acc: 0.8571
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_5.pth
# No improvement, early stopping may happen after 1 more epochs if no improvements
# Epoch 6/20 [Train]:   0%|          | 0/1430 [00:00<?, ?it/s]
# Epoch 6/20 [Validation]:   0%|          | 0/427 [00:00<?, ?it/s]
# Epoch 6/20 | Train loss: 0.2348 | Train acc: 0.8976 | Val loss: 0.3075 | Val acc: 0.8663
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_6.pth
# Model saved!
# Epoch 7/20 [Train]:   0%|          | 0/1430 [00:00<?, ?it/s]
# Epoch 7/20 [Validation]:   0%|          | 0/427 [00:00<?, ?it/s]
# Epoch 7/20 | Train loss: 0.2242 | Train acc: 0.9017 | Val loss: 0.3317 | Val acc: 0.8467
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_7.pth
# No improvement, early stopping may happen after 2 more epochs if no improvements
# Epoch 8/20 [Train]:   0%|          | 0/1430 [00:00<?, ?it/s]
# Epoch 8/20 [Validation]:   0%|          | 0/427 [00:00<?, ?it/s]
# Epoch 8/20 | Train loss: 0.1917 | Train acc: 0.9145 | Val loss: 0.2909 | Val acc: 0.8791
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_8.pth
# Model saved!
# Epoch 9/20 [Train]:   0%|          | 0/1430 [00:00<?, ?it/s]
# Epoch 9/20 [Validation]:   0%|          | 0/427 [00:00<?, ?it/s]
# Epoch 9/20 | Train loss: 0.1798 | Train acc: 0.9193 | Val loss: 0.2889 | Val acc: 0.8832
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_9.pth
# No improvement, early stopping may happen after 2 more epochs if no improvements
# Epoch 10/20 [Train]:   0%|          | 0/1430 [00:00<?, ?it/s]
# Epoch 10/20 [Validation]:   0%|          | 0/427 [00:00<?, ?it/s]
# Epoch 10/20 | Train loss: 0.1716 | Train acc: 0.9231 | Val loss: 0.2990 | Val acc: 0.8806
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_10.pth
# No improvement, early stopping may happen after 1 more epochs if no improvements
# Epoch 11/20 [Train]:   0%|          | 0/1430 [00:00<?, ?it/s]
# Epoch 11/20 [Validation]:   0%|          | 0/427 [00:00<?, ?it/s]
# Epoch 11/20 | Train loss: 0.1637 | Train acc: 0.9268 | Val loss: 0.2987 | Val acc: 0.8808
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_11.pth
# Training stopped early at epoch 11
# [Test]:   0%|          | 0/427 [00:00<?, ?it/s]
# Test loss: 0.29867191448699315 | Test acc: 0.8807652135671485

# %%
plot_loss(training_losses=history["train_losses"], val_losses=history["val_losses"], last_model_saved_epoch=history['last_model_saved_epoch'])

# %%
plot_acc(training_accs=history["train_accs"], val_accs=history["val_accs"], last_model_saved_epoch=history['last_model_saved_epoch'])

# %%
from google.colab import runtime
runtime.unassign()
